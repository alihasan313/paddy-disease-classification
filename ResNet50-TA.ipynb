# %%
# SYSTEM & FILE (Untuk akses Drive, folder, dan simpan hasil)
from google.colab import drive
import os
from glob import glob
import pickle
import gc # Penting buat bersihin RAM tiap ganti Fold

# DATA & VISUALISASI (Olah gambar dan bikin grafik)
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2

# TENSORFLOW/KERAS
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# MACHINE LEARNING UTILS (Bagi data dan evaluasi)
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
# Mount Google Drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Configuration & Hyperparameters

# !cp -r "/content/drive/MyDrive/22-023_Ali Ridho/Dataset" "/content/"
DATASET_PATH = "/content/Dataset"  # Path lokal di colab

# Hyperparameters
IMG_SIZE = 224
BATCH_SIZE = 32
EPOCHS = 100
PATIENCE = 10
LEARNING_RATE = 0.001
NUM_CLASSES = 4
K_FOLDS = 5
TEST_SPLIT = 0.2  # 80% train, 20% test (unseen)

# PILIH MODE EVALUASI
USE_AVG = True

# Random seed untuk reproducibility
SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
# Load dan Prepare Dataset

def load_dataset(dataset_path):
    images = []
    labels = []
    class_names = sorted(os.listdir(dataset_path))

    print(f"Class names: {class_names}")

    for idx, class_name in enumerate(class_names):
        class_path = os.path.join(dataset_path, class_name)
        if not os.path.isdir(class_path):
            continue

        image_files = glob(os.path.join(class_path, '*.*'))
        print(f"Class {class_name}: {len(image_files)} images")

        for img_path in image_files:
            try:
                img = cv2.imread(img_path)
                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
                images.append(img)
                labels.append(idx)
            except Exception as e:
                print(f"Error loading {img_path}: {e}")

    images = np.array(images, dtype='float32')
    labels = np.array(labels)

    print(f"\nTotal images: {len(images)}")
    print(f"Image shape: {images.shape}")
    print(f"Image value range: [{images.min()}, {images.max()}]")
    print(f"Labels shape: {labels.shape}")

    return images, labels, class_names

# Load dataset dari local storage
print(f"Loading dataset from: {DATASET_PATH}")
X, y, class_names = load_dataset(DATASET_PATH)

# Rescale images ke [0, 1]
print("\nRescaling images from [0, 255] to [0, 1]...")
X = X / 255.0
print(f"After rescaling: [{X.min()}, {X.max()}]")

# Split train-test (test adalah unseen data)
X_train_full, X_test, y_train_full, y_test = train_test_split(
    X, y, test_size=TEST_SPLIT, stratify=y, random_state=SEED
)

print(f"\nTrain set: {len(X_train_full)} images")
print(f"Test set (unseen): {len(X_test)} images")
# Out:
# Loading dataset from: /content/Dataset
# Class names: ['blast', 'brown_spot', 'hispa', 'normal']
# Class blast: 1738 images
# Class brown_spot: 965 images
# Class hispa: 1594 images
# Class normal: 1764 images
#
# Total images: 6061
# Image shape: (6061, 224, 224, 3)
# Image value range: [0.0, 255.0]
# Labels shape: (6061,)
#
# Rescaling images from [0, 255] to [0, 1]...
# After rescaling: [0.0, 1.0]
#
# Train set: 4848 images
# Test set (unseen): 1213 images

# %%
# TRIPLET ATTENTION MODULES
class ZPool(layers.Layer):
    """Z-Pooling: Concatenate max and mean pooling along channel dimension"""
    def call(self, x):
        max_pool = tf.reduce_max(x, axis=-1, keepdims=True) #ambil nilai max
        mean_pool = tf.reduce_mean(x, axis=-1, keepdims=True) #ambil nilai rata-rata
        return tf.concat([max_pool, mean_pool], axis=-1)

#conv 7x7
class AttentionGate(layers.Layer):
    def __init__(self, kernel_size=7, **kwargs):
        super(AttentionGate, self).__init__(**kwargs)
        self.compress = ZPool()
        self.conv = layers.Conv2D(1, kernel_size, padding='same', use_bias=False)
        self.bn = layers.BatchNormalization()
        self.activation = layers.Activation('sigmoid')

    def call(self, x):
        x_compress = self.compress(x) #ambil nilai avg & max
        x_out = self.conv(x_compress) #conv 7x7 dan digabung
        x_out = self.bn(x_out)
        scale = self.activation(x_out) #sigmoid
        return x * scale # * attention weight


class TripletAttention(layers.Layer):
    """
    Triplet Attention Module
    Menangkap dependencies cross-dimension: H-W, C-W, H-C
    Dengan mentranspose, kita "menipu" AttentionGate untuk berpikir bahwa channel atau width adalah
    dimensi spasial, sehingga perhatian diterapkan ke dimensi yang berbeda.
    """
    def __init__(self, **kwargs):
        super(TripletAttention, self).__init__(**kwargs)
        self.cw_gate = AttentionGate()
        self.hc_gate = AttentionGate()
        self.hw_gate = AttentionGate()

    def call(self, x):
        # cabang 1 H-W (tanpa transpose)
        x_hw = self.hw_gate(x)

        # Cabang 2C-W
        x_perm1 = tf.transpose(x, perm=[0, 3, 2, 1])  # Transpose: (B, H, W, C) -> (B, C, W, H)
        x_cw = self.cw_gate(x_perm1)
        x_cw = tf.transpose(x_cw, perm=[0, 3, 2, 1]) # Transpose kembali: (B, C, W, H) -> (B, H, W, C)

        # Cabang 3 H-C
        x_perm2 = tf.transpose(x, perm=[0, 1, 3, 2]) # Transpose: (B, H, W, C) -> (B, H, C, W)
        x_hc = self.hc_gate(x_perm2)
        x_hc = tf.transpose(x_hc, perm=[0, 1, 3, 2]) # Transpose kembali: (B, H, C, W) -> (B, H, W, C)

        return (x_hw + x_cw + x_hc) / 3 # Rata-rata dari ketiga cabang

# %%
# BOTTLENECK BLOCK

def bottleneck_block(x, filters, stride=1, downsample=False, name=None):
    shortcut = x
    in_channels = x.shape[-1]

    # Conv 1x1
    x = layers.Conv2D(filters, (1, 1), strides=stride, padding='same',
                     use_bias=False, name=f"{name}_1_conv")(x)
    x = layers.BatchNormalization(name=f"{name}_1_bn")(x)
    x = layers.Activation('relu', name=f"{name}_1_relu")(x)

    # Conv 3x3
    x = layers.Conv2D(filters, (3, 3), strides=1, padding='same',
                     use_bias=False, name=f"{name}_2_conv")(x)
    x = layers.BatchNormalization(name=f"{name}_2_bn")(x)
    x = layers.Activation('relu', name=f"{name}_2_relu")(x)

    # Conv 1x1N
    x = layers.Conv2D(filters * 4, (1, 1), strides=1, padding='same',
                     use_bias=False, name=f"{name}_3_conv")(x)
    x = layers.BatchNormalization(name=f"{name}_3_bn")(x)

    # Shortcut connection
    if downsample or in_channels != filters * 4:
        shortcut = layers.Conv2D(filters * 4, (1, 1), strides=stride,
                                padding='same', use_bias=False,
                                name=f"{name}_0_conv")(shortcut)
        shortcut = layers.BatchNormalization(name=f"{name}_0_bn")(shortcut)

    # Add shortcut + relu
    x = layers.Add(name=f"{name}_add")([x, shortcut])
    x = layers.Activation('relu', name=f"{name}_out")(x)

    return x

# %%
# ResNet-50 + Triplet Attention Architecture
def build_resnet50_triplet_attention(num_classes=4, input_shape=(224, 224, 3),use_attention=True):
    inputs = layers.Input(shape=input_shape)

    # Initial layers
    x = layers.Conv2D(64, (7, 7), strides=2, padding='same', use_bias=False, name="stem_conv")(inputs)
    x = layers.BatchNormalization(name="stem_bn")(x)
    x = layers.Activation('relu', name="stem_relu")(x)
    x = layers.MaxPooling2D((3, 3), strides=2, padding='same', name="stem_pool")(x)

    # Stage
    block_counts = [3, 4, 6, 3]
    filter_sizes = [64, 128, 256, 512]

    for stage, (filters, blocks) in enumerate(zip(filter_sizes, block_counts)):
        print(f"Building Stage {stage + 2} with {blocks} blocks, filters={filters}")

        for block in range(blocks):
            downsample = (block == 0)
            stride = 2 if (block == 0 and stage != 0) else 1
            block_name = f"stage{stage + 2}_block{block + 1}"

            x = bottleneck_block(x, filters, stride=stride,
                               downsample=downsample, name=block_name)

        # TRIPLET ATTENTION DI AKHIR SETIAP STAGE
        if use_attention:
            x = TripletAttention(name=f"triplet_attention_stage{stage + 2}")(x)
            print(f"  ✅ Triplet Attention added at Stage {stage + 2}")

    # CLASSIFICATION HEAD
    x = layers.GlobalAveragePooling2D(name="avg_pool")(x)
    outputs = layers.Dense(num_classes, activation='softmax', name="predictions")(x)
    model_name = "ResNet50_TA" if use_attention else "ResNet50_Baseline"
    model = models.Model(inputs, outputs, name=model_name)

    return model

# SUMMARY Model
model = build_resnet50_triplet_attention(
    num_classes=NUM_CLASSES,
    input_shape=(IMG_SIZE, IMG_SIZE, 3),
    use_attention=True
)
model.summary()

# Cleanup
import gc
del model
tf.keras.backend.clear_session()
gc.collect()
# Out:
# Building Stage 2 with 3 blocks, filters=64
#   ✅ Triplet Attention added at Stage 2
# Building Stage 3 with 4 blocks, filters=128
#   ✅ Triplet Attention added at Stage 3
# Building Stage 4 with 6 blocks, filters=256
#   ✅ Triplet Attention added at Stage 4
# Building Stage 5 with 3 blocks, filters=512
#   ✅ Triplet Attention added at Stage 5
# Model: "ResNet50_TA"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_conv (Conv2D)  │ (None, 112, 112,  │      9,408 │ input_layer[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_bn             │ (None, 112, 112,  │        256 │ stem_conv[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_relu           │ (None, 112, 112,  │          0 │ stem_bn[0][0]     │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_pool           │ (None, 56, 56,    │          0 │ stem_relu[0][0]   │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_1_co… │ (None, 56, 56,    │      4,096 │ stem_pool[0][0]   │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_1_bn  │ (None, 56, 56,    │        256 │ stage2_block1_1_… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_1_re… │ (None, 56, 56,    │          0 │ stage2_block1_1_… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_2_co… │ (None, 56, 56,    │     36,864 │ stage2_block1_1_… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_2_bn  │ (None, 56, 56,    │        256 │ stage2_block1_2_… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_2_re… │ (None, 56, 56,    │          0 │ stage2_block1_2_… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_3_co… │ (None, 56, 56,    │     16,384 │ stage2_block1_2_… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_0_co… │ (None, 56, 56,    │     16,384 │ stem_pool[0][0]   │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_3_bn  │ (None, 56, 56,    │      1,024 │ stage2_block1_3_… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_0_bn  │ (None, 56, 56,    │      1,024 │ stage2_block1_0_… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_add   │ (None, 56, 56,    │          0 │ stage2_block1_3_… │
# │ (Add)               │ 256)              │            │ stage2_block1_0_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_out   │ (None, 56, 56,    │          0 │ stage2_block1_ad… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block2_1_co… │ (None, 56, 56,    │     16,384 │ stage2_block1_ou… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block2_1_bn  │ (None, 56, 56,    │        256 │ stage2_block2_1_… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block2_1_re… │ (None, 56, 56,    │          0 │ stage2_block2_1_… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block2_2_co… │ (None, 56, 56,    │     36,864 │ stage2_block2_1_… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block2_2_bn  │ (None, 56, 56,    │        256 │ stage2_block2_2_… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block2_2_re… │ (None, 56, 56,    │          0 │ stage2_block2_2_… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block2_3_co… │ (None, 56, 56,    │     16,384 │ stage2_block2_2_… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block2_3_bn  │ (None, 56, 56,    │      1,024 │ stage2_block2_3_… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block2_add   │ (None, 56, 56,    │          0 │ stage2_block2_3_… │
# │ (Add)               │ 256)              │            │ stage2_block1_ou… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block2_out   │ (None, 56, 56,    │          0 │ stage2_block2_ad… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block3_1_co… │ (None, 56, 56,    │     16,384 │ stage2_block2_ou… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block3_1_bn  │ (None, 56, 56,    │        256 │ stage2_block3_1_… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block3_1_re… │ (None, 56, 56,    │          0 │ stage2_block3_1_… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block3_2_co… │ (None, 56, 56,    │     36,864 │ stage2_block3_1_… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block3_2_bn  │ (None, 56, 56,    │        256 │ stage2_block3_2_… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block3_2_re… │ (None, 56, 56,    │          0 │ stage2_block3_2_… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block3_3_co… │ (None, 56, 56,    │     16,384 │ stage2_block3_2_… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block3_3_bn  │ (None, 56, 56,    │      1,024 │ stage2_block3_3_… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block3_add   │ (None, 56, 56,    │          0 │ stage2_block3_3_… │
# │ (Add)               │ 256)              │            │ stage2_block2_ou… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block3_out   │ (None, 56, 56,    │          0 │ stage2_block3_ad… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ triplet_attention_… │ (None, 56, 56,    │        306 │ stage2_block3_ou… │
# │ (TripletAttention)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_1_co… │ (None, 28, 28,    │     32,768 │ triplet_attentio… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_1_bn  │ (None, 28, 28,    │        512 │ stage3_block1_1_… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_1_re… │ (None, 28, 28,    │          0 │ stage3_block1_1_… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_2_co… │ (None, 28, 28,    │    147,456 │ stage3_block1_1_… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_2_bn  │ (None, 28, 28,    │        512 │ stage3_block1_2_… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_2_re… │ (None, 28, 28,    │          0 │ stage3_block1_2_… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_3_co… │ (None, 28, 28,    │     65,536 │ stage3_block1_2_… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_0_co… │ (None, 28, 28,    │    131,072 │ triplet_attentio… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_3_bn  │ (None, 28, 28,    │      2,048 │ stage3_block1_3_… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_0_bn  │ (None, 28, 28,    │      2,048 │ stage3_block1_0_… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_add   │ (None, 28, 28,    │          0 │ stage3_block1_3_… │
# │ (Add)               │ 512)              │            │ stage3_block1_0_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_out   │ (None, 28, 28,    │          0 │ stage3_block1_ad… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block2_1_co… │ (None, 28, 28,    │     65,536 │ stage3_block1_ou… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block2_1_bn  │ (None, 28, 28,    │        512 │ stage3_block2_1_… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block2_1_re… │ (None, 28, 28,    │          0 │ stage3_block2_1_… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block2_2_co… │ (None, 28, 28,    │    147,456 │ stage3_block2_1_… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block2_2_bn  │ (None, 28, 28,    │        512 │ stage3_block2_2_… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block2_2_re… │ (None, 28, 28,    │          0 │ stage3_block2_2_… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block2_3_co… │ (None, 28, 28,    │     65,536 │ stage3_block2_2_… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block2_3_bn  │ (None, 28, 28,    │      2,048 │ stage3_block2_3_… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block2_add   │ (None, 28, 28,    │          0 │ stage3_block2_3_… │
# │ (Add)               │ 512)              │            │ stage3_block1_ou… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block2_out   │ (None, 28, 28,    │          0 │ stage3_block2_ad… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block3_1_co… │ (None, 28, 28,    │     65,536 │ stage3_block2_ou… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block3_1_bn  │ (None, 28, 28,    │        512 │ stage3_block3_1_… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block3_1_re… │ (None, 28, 28,    │          0 │ stage3_block3_1_… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block3_2_co… │ (None, 28, 28,    │    147,456 │ stage3_block3_1_… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block3_2_bn  │ (None, 28, 28,    │        512 │ stage3_block3_2_… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block3_2_re… │ (None, 28, 28,    │          0 │ stage3_block3_2_… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block3_3_co… │ (None, 28, 28,    │     65,536 │ stage3_block3_2_… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block3_3_bn  │ (None, 28, 28,    │      2,048 │ stage3_block3_3_… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block3_add   │ (None, 28, 28,    │          0 │ stage3_block3_3_… │
# │ (Add)               │ 512)              │            │ stage3_block2_ou… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block3_out   │ (None, 28, 28,    │          0 │ stage3_block3_ad… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block4_1_co… │ (None, 28, 28,    │     65,536 │ stage3_block3_ou… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block4_1_bn  │ (None, 28, 28,    │        512 │ stage3_block4_1_… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block4_1_re… │ (None, 28, 28,    │          0 │ stage3_block4_1_… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block4_2_co… │ (None, 28, 28,    │    147,456 │ stage3_block4_1_… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block4_2_bn  │ (None, 28, 28,    │        512 │ stage3_block4_2_… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block4_2_re… │ (None, 28, 28,    │          0 │ stage3_block4_2_… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block4_3_co… │ (None, 28, 28,    │     65,536 │ stage3_block4_2_… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block4_3_bn  │ (None, 28, 28,    │      2,048 │ stage3_block4_3_… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block4_add   │ (None, 28, 28,    │          0 │ stage3_block4_3_… │
# │ (Add)               │ 512)              │            │ stage3_block3_ou… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block4_out   │ (None, 28, 28,    │          0 │ stage3_block4_ad… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ triplet_attention_… │ (None, 28, 28,    │        306 │ stage3_block4_ou… │
# │ (TripletAttention)  │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_1_co… │ (None, 14, 14,    │    131,072 │ triplet_attentio… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_1_bn  │ (None, 14, 14,    │      1,024 │ stage4_block1_1_… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_1_re… │ (None, 14, 14,    │          0 │ stage4_block1_1_… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_2_co… │ (None, 14, 14,    │    589,824 │ stage4_block1_1_… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_2_bn  │ (None, 14, 14,    │      1,024 │ stage4_block1_2_… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_2_re… │ (None, 14, 14,    │          0 │ stage4_block1_2_… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_3_co… │ (None, 14, 14,    │    262,144 │ stage4_block1_2_… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_0_co… │ (None, 14, 14,    │    524,288 │ triplet_attentio… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_3_bn  │ (None, 14, 14,    │      4,096 │ stage4_block1_3_… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_0_bn  │ (None, 14, 14,    │      4,096 │ stage4_block1_0_… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_add   │ (None, 14, 14,    │          0 │ stage4_block1_3_… │
# │ (Add)               │ 1024)             │            │ stage4_block1_0_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_out   │ (None, 14, 14,    │          0 │ stage4_block1_ad… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block2_1_co… │ (None, 14, 14,    │    262,144 │ stage4_block1_ou… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block2_1_bn  │ (None, 14, 14,    │      1,024 │ stage4_block2_1_… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block2_1_re… │ (None, 14, 14,    │          0 │ stage4_block2_1_… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block2_2_co… │ (None, 14, 14,    │    589,824 │ stage4_block2_1_… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block2_2_bn  │ (None, 14, 14,    │      1,024 │ stage4_block2_2_… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block2_2_re… │ (None, 14, 14,    │          0 │ stage4_block2_2_… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block2_3_co… │ (None, 14, 14,    │    262,144 │ stage4_block2_2_… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block2_3_bn  │ (None, 14, 14,    │      4,096 │ stage4_block2_3_… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block2_add   │ (None, 14, 14,    │          0 │ stage4_block2_3_… │
# │ (Add)               │ 1024)             │            │ stage4_block1_ou… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block2_out   │ (None, 14, 14,    │          0 │ stage4_block2_ad… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block3_1_co… │ (None, 14, 14,    │    262,144 │ stage4_block2_ou… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block3_1_bn  │ (None, 14, 14,    │      1,024 │ stage4_block3_1_… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block3_1_re… │ (None, 14, 14,    │          0 │ stage4_block3_1_… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block3_2_co… │ (None, 14, 14,    │    589,824 │ stage4_block3_1_… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block3_2_bn  │ (None, 14, 14,    │      1,024 │ stage4_block3_2_… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block3_2_re… │ (None, 14, 14,    │          0 │ stage4_block3_2_… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block3_3_co… │ (None, 14, 14,    │    262,144 │ stage4_block3_2_… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block3_3_bn  │ (None, 14, 14,    │      4,096 │ stage4_block3_3_… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block3_add   │ (None, 14, 14,    │          0 │ stage4_block3_3_… │
# │ (Add)               │ 1024)             │            │ stage4_block2_ou… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block3_out   │ (None, 14, 14,    │          0 │ stage4_block3_ad… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block4_1_co… │ (None, 14, 14,    │    262,144 │ stage4_block3_ou… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block4_1_bn  │ (None, 14, 14,    │      1,024 │ stage4_block4_1_… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block4_1_re… │ (None, 14, 14,    │          0 │ stage4_block4_1_… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block4_2_co… │ (None, 14, 14,    │    589,824 │ stage4_block4_1_… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block4_2_bn  │ (None, 14, 14,    │      1,024 │ stage4_block4_2_… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block4_2_re… │ (None, 14, 14,    │          0 │ stage4_block4_2_… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block4_3_co… │ (None, 14, 14,    │    262,144 │ stage4_block4_2_… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block4_3_bn  │ (None, 14, 14,    │      4,096 │ stage4_block4_3_… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block4_add   │ (None, 14, 14,    │          0 │ stage4_block4_3_… │
# │ (Add)               │ 1024)             │            │ stage4_block3_ou… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block4_out   │ (None, 14, 14,    │          0 │ stage4_block4_ad… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block5_1_co… │ (None, 14, 14,    │    262,144 │ stage4_block4_ou… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block5_1_bn  │ (None, 14, 14,    │      1,024 │ stage4_block5_1_… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block5_1_re… │ (None, 14, 14,    │          0 │ stage4_block5_1_… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block5_2_co… │ (None, 14, 14,    │    589,824 │ stage4_block5_1_… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block5_2_bn  │ (None, 14, 14,    │      1,024 │ stage4_block5_2_… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block5_2_re… │ (None, 14, 14,    │          0 │ stage4_block5_2_… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block5_3_co… │ (None, 14, 14,    │    262,144 │ stage4_block5_2_… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block5_3_bn  │ (None, 14, 14,    │      4,096 │ stage4_block5_3_… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block5_add   │ (None, 14, 14,    │          0 │ stage4_block5_3_… │
# │ (Add)               │ 1024)             │            │ stage4_block4_ou… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block5_out   │ (None, 14, 14,    │          0 │ stage4_block5_ad… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block6_1_co… │ (None, 14, 14,    │    262,144 │ stage4_block5_ou… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block6_1_bn  │ (None, 14, 14,    │      1,024 │ stage4_block6_1_… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block6_1_re… │ (None, 14, 14,    │          0 │ stage4_block6_1_… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block6_2_co… │ (None, 14, 14,    │    589,824 │ stage4_block6_1_… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block6_2_bn  │ (None, 14, 14,    │      1,024 │ stage4_block6_2_… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block6_2_re… │ (None, 14, 14,    │          0 │ stage4_block6_2_… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block6_3_co… │ (None, 14, 14,    │    262,144 │ stage4_block6_2_… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block6_3_bn  │ (None, 14, 14,    │      4,096 │ stage4_block6_3_… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block6_add   │ (None, 14, 14,    │          0 │ stage4_block6_3_… │
# │ (Add)               │ 1024)             │            │ stage4_block5_ou… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block6_out   │ (None, 14, 14,    │          0 │ stage4_block6_ad… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ triplet_attention_… │ (None, 14, 14,    │        306 │ stage4_block6_ou… │
# │ (TripletAttention)  │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block1_1_co… │ (None, 7, 7, 512) │    524,288 │ triplet_attentio… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block1_1_bn  │ (None, 7, 7, 512) │      2,048 │ stage5_block1_1_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block1_1_re… │ (None, 7, 7, 512) │          0 │ stage5_block1_1_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block1_2_co… │ (None, 7, 7, 512) │  2,359,296 │ stage5_block1_1_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block1_2_bn  │ (None, 7, 7, 512) │      2,048 │ stage5_block1_2_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block1_2_re… │ (None, 7, 7, 512) │          0 │ stage5_block1_2_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block1_3_co… │ (None, 7, 7,      │  1,048,576 │ stage5_block1_2_… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block1_0_co… │ (None, 7, 7,      │  2,097,152 │ triplet_attentio… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block1_3_bn  │ (None, 7, 7,      │      8,192 │ stage5_block1_3_… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block1_0_bn  │ (None, 7, 7,      │      8,192 │ stage5_block1_0_… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block1_add   │ (None, 7, 7,      │          0 │ stage5_block1_3_… │
# │ (Add)               │ 2048)             │            │ stage5_block1_0_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block1_out   │ (None, 7, 7,      │          0 │ stage5_block1_ad… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block2_1_co… │ (None, 7, 7, 512) │  1,048,576 │ stage5_block1_ou… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block2_1_bn  │ (None, 7, 7, 512) │      2,048 │ stage5_block2_1_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block2_1_re… │ (None, 7, 7, 512) │          0 │ stage5_block2_1_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block2_2_co… │ (None, 7, 7, 512) │  2,359,296 │ stage5_block2_1_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block2_2_bn  │ (None, 7, 7, 512) │      2,048 │ stage5_block2_2_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block2_2_re… │ (None, 7, 7, 512) │          0 │ stage5_block2_2_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block2_3_co… │ (None, 7, 7,      │  1,048,576 │ stage5_block2_2_… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block2_3_bn  │ (None, 7, 7,      │      8,192 │ stage5_block2_3_… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block2_add   │ (None, 7, 7,      │          0 │ stage5_block2_3_… │
# │ (Add)               │ 2048)             │            │ stage5_block1_ou… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block2_out   │ (None, 7, 7,      │          0 │ stage5_block2_ad… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block3_1_co… │ (None, 7, 7, 512) │  1,048,576 │ stage5_block2_ou… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block3_1_bn  │ (None, 7, 7, 512) │      2,048 │ stage5_block3_1_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block3_1_re… │ (None, 7, 7, 512) │          0 │ stage5_block3_1_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block3_2_co… │ (None, 7, 7, 512) │  2,359,296 │ stage5_block3_1_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block3_2_bn  │ (None, 7, 7, 512) │      2,048 │ stage5_block3_2_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block3_2_re… │ (None, 7, 7, 512) │          0 │ stage5_block3_2_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block3_3_co… │ (None, 7, 7,      │  1,048,576 │ stage5_block3_2_… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block3_3_bn  │ (None, 7, 7,      │      8,192 │ stage5_block3_3_… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block3_add   │ (None, 7, 7,      │          0 │ stage5_block3_3_… │
# │ (Add)               │ 2048)             │            │ stage5_block2_ou… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block3_out   │ (None, 7, 7,      │          0 │ stage5_block3_ad… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ triplet_attention_… │ (None, 7, 7,      │        306 │ stage5_block3_ou… │
# │ (TripletAttention)  │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ avg_pool            │ (None, 2048)      │          0 │ triplet_attentio… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ predictions (Dense) │ (None, 4)         │      8,196 │ avg_pool[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 23,570,572 (89.91 MB)
#  Trainable params: 23,517,428 (89.71 MB)
#  Non-trainable params: 53,144 (207.59 KB)
# 0

# %%
# K-Fold Cross Validation Setup

kfold = StratifiedKFold(n_splits=K_FOLDS, shuffle=True, random_state=SEED)

# Storage untuk hasil setiap fold
fold_histories = []
fold_scores = []
fold_models = []

# %%
# Tahap training K-fold

for fold, (train_idx, val_idx) in enumerate(kfold.split(X_train_full, y_train_full)):
    print(f"\nFOLD {fold + 1}/{K_FOLDS}")

    # Pembagian data latih & validasi berdasarkan index K-Fold
    X_train_fold, X_val_fold = X_train_full[train_idx], X_train_full[val_idx]
    y_train_fold, y_val_fold = y_train_full[train_idx], y_train_full[val_idx]

    # mengubah label angka (0-3) menjadi vektor biner
    y_train_cat = tf.keras.utils.to_categorical(y_train_fold, NUM_CLASSES)
    y_val_cat = tf.keras.utils.to_categorical(y_val_fold, NUM_CLASSES)

    # Re-inisialisasi Model
    model = build_resnet50_triplet_attention(
        num_classes=NUM_CLASSES,
        input_shape=(IMG_SIZE, IMG_SIZE, 3),
        use_attention=True # Set True jika masuk skenario Triplet Attention
    )

    # Konfigurasi Optimizer
    model.compile(
        optimizer=optimizers.Adam(learning_rate=LEARNING_RATE),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    # callbacks
    checkpoint_path = f'/content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold{fold+1}_best.keras'
    os.makedirs(os.path.dirname(checkpoint_path), exist_ok=True)
    callbacks = [
        EarlyStopping(
            monitor='val_loss',
            patience=PATIENCE,
            restore_best_weights=True,
            verbose=1),

        ModelCheckpoint(
            checkpoint_path,
            monitor='val_accuracy',
            save_best_only=True,
            verbose=1)
    ]

    # augmentasi
    datagen = ImageDataGenerator(
        rotation_range=20, width_shift_range=0.2, height_shift_range=0.2,
        horizontal_flip=True, zoom_range=0.2, shear_range=0.2, fill_mode='nearest'
    )

    # proses Training
    history = model.fit(
        datagen.flow(X_train_fold, y_train_cat, batch_size=BATCH_SIZE),
        validation_data=(X_val_fold, y_val_cat),
        epochs=EPOCHS,
        callbacks=callbacks,
        verbose=1
    )

    # Evaluasi performa fold saat ini
    val_loss, val_acc = model.evaluate(X_val_fold, y_val_cat, verbose=0)
    print(f"\nFold {fold + 1} - Validation Accuracy: {val_acc:.4f}")

    # penyimpanan log history dan model
    fold_histories.append(history.history)
    fold_scores.append({'val_loss': val_loss, 'val_accuracy': val_acc})
    fold_models.append(model)

    # 10. Manajemen Memori (Menghapus cache RAM/GPU agar tidak crash di fold berikutnya)
    gc.collect()
    tf.keras.backend.clear_session()
# Out:
# FOLD 1/5
# Building Stage 2 with 3 blocks, filters=64
#   ✅ Triplet Attention added at Stage 2
# Building Stage 3 with 4 blocks, filters=128
#   ✅ Triplet Attention added at Stage 3
# Building Stage 4 with 6 blocks, filters=256
#   ✅ Triplet Attention added at Stage 4
# Building Stage 5 with 3 blocks, filters=512
#   ✅ Triplet Attention added at Stage 5
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 860ms/step - accuracy: 0.3361 - loss: 1.7380
# Epoch 1: val_accuracy improved from -inf to 0.29072, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold1_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 234s 1s/step - accuracy: 0.3363 - loss: 1.7356 - val_accuracy: 0.2907 - val_loss: 1.6082
# Epoch 2/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.4267 - loss: 1.2199
# Epoch 2: val_accuracy did not improve from 0.29072
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 334ms/step - accuracy: 0.4269 - loss: 1.2197 - val_accuracy: 0.2907 - val_loss: 3.0575
# Epoch 3/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.4893 - loss: 1.1294
# Epoch 3: val_accuracy improved from 0.29072 to 0.30928, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold1_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 42s 345ms/step - accuracy: 0.4896 - loss: 1.1291 - val_accuracy: 0.3093 - val_loss: 2.0394
# Epoch 4/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.5630 - loss: 1.0066
# Epoch 4: val_accuracy improved from 0.30928 to 0.44021, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold1_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 42s 344ms/step - accuracy: 0.5630 - loss: 1.0065 - val_accuracy: 0.4402 - val_loss: 1.2526
# Epoch 5/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.6112 - loss: 0.9328
# Epoch 5: val_accuracy did not improve from 0.44021
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 327ms/step - accuracy: 0.6113 - loss: 0.9327 - val_accuracy: 0.3588 - val_loss: 2.7026
# Epoch 6/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 0.6534 - loss: 0.8609
# Epoch 6: val_accuracy did not improve from 0.44021
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 324ms/step - accuracy: 0.6534 - loss: 0.8609 - val_accuracy: 0.3948 - val_loss: 2.7848
# Epoch 7/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.7000 - loss: 0.7832
# Epoch 7: val_accuracy did not improve from 0.44021
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 331ms/step - accuracy: 0.6999 - loss: 0.7834 - val_accuracy: 0.4206 - val_loss: 3.1615
# Epoch 8/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.7397 - loss: 0.7143
# Epoch 8: val_accuracy improved from 0.44021 to 0.45876, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold1_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 44s 356ms/step - accuracy: 0.7396 - loss: 0.7144 - val_accuracy: 0.4588 - val_loss: 1.4827
# Epoch 9/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.7466 - loss: 0.6740
# Epoch 9: val_accuracy did not improve from 0.45876
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 336ms/step - accuracy: 0.7467 - loss: 0.6740 - val_accuracy: 0.4031 - val_loss: 4.5963
# Epoch 10/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.7472 - loss: 0.6840
# Epoch 10: val_accuracy did not improve from 0.45876
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 329ms/step - accuracy: 0.7473 - loss: 0.6839 - val_accuracy: 0.4474 - val_loss: 4.0805
# Epoch 11/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.8003 - loss: 0.5585
# Epoch 11: val_accuracy did not improve from 0.45876
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 326ms/step - accuracy: 0.8003 - loss: 0.5586 - val_accuracy: 0.4124 - val_loss: 3.2373
# Epoch 12/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - accuracy: 0.8130 - loss: 0.5399
# Epoch 12: val_accuracy improved from 0.45876 to 0.68763, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold1_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 337ms/step - accuracy: 0.8130 - loss: 0.5398 - val_accuracy: 0.6876 - val_loss: 0.9177
# Epoch 13/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.8013 - loss: 0.5627
# Epoch 13: val_accuracy improved from 0.68763 to 0.70515, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold1_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 42s 346ms/step - accuracy: 0.8012 - loss: 0.5628 - val_accuracy: 0.7052 - val_loss: 0.7719
# Epoch 14/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.8349 - loss: 0.4656
# Epoch 14: val_accuracy improved from 0.70515 to 0.77010, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold1_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 42s 346ms/step - accuracy: 0.8349 - loss: 0.4658 - val_accuracy: 0.7701 - val_loss: 0.5492
# Epoch 15/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.8476 - loss: 0.4644
# Epoch 15: val_accuracy did not improve from 0.77010
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 323ms/step - accuracy: 0.8475 - loss: 0.4644 - val_accuracy: 0.3897 - val_loss: 5.0893
# Epoch 16/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 0.8462 - loss: 0.4333
# Epoch 16: val_accuracy did not improve from 0.77010
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 324ms/step - accuracy: 0.8463 - loss: 0.4334 - val_accuracy: 0.5082 - val_loss: 1.7858
# Epoch 17/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.8433 - loss: 0.4276
# Epoch 17: val_accuracy did not improve from 0.77010
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 329ms/step - accuracy: 0.8433 - loss: 0.4276 - val_accuracy: 0.5577 - val_loss: 3.1505
# Epoch 18/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.8635 - loss: 0.3961
# Epoch 18: val_accuracy improved from 0.77010 to 0.82577, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold1_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 42s 342ms/step - accuracy: 0.8635 - loss: 0.3961 - val_accuracy: 0.8258 - val_loss: 0.4693
# Epoch 19/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.8710 - loss: 0.3867
# Epoch 19: val_accuracy did not improve from 0.82577
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 331ms/step - accuracy: 0.8710 - loss: 0.3866 - val_accuracy: 0.7134 - val_loss: 0.9812
# Epoch 20/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 0.8671 - loss: 0.3586
# Epoch 20: val_accuracy did not improve from 0.82577
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 324ms/step - accuracy: 0.8672 - loss: 0.3584 - val_accuracy: 0.6784 - val_loss: 1.2859
# Epoch 21/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.8893 - loss: 0.3377
# Epoch 21: val_accuracy did not improve from 0.82577
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 328ms/step - accuracy: 0.8893 - loss: 0.3378 - val_accuracy: 0.5062 - val_loss: 2.5444
# Epoch 22/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.8900 - loss: 0.3477
# Epoch 22: val_accuracy did not improve from 0.82577
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 331ms/step - accuracy: 0.8900 - loss: 0.3476 - val_accuracy: 0.6268 - val_loss: 1.5618
# Epoch 23/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.9042 - loss: 0.3011
# Epoch 23: val_accuracy did not improve from 0.82577
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 335ms/step - accuracy: 0.9042 - loss: 0.3011 - val_accuracy: 0.4340 - val_loss: 2.3705
# Epoch 24/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.9001 - loss: 0.3101
# Epoch 24: val_accuracy did not improve from 0.82577
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 330ms/step - accuracy: 0.9001 - loss: 0.3102 - val_accuracy: 0.7392 - val_loss: 0.7635
# Epoch 25/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.9063 - loss: 0.2709
# Epoch 25: val_accuracy did not improve from 0.82577
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 327ms/step - accuracy: 0.9063 - loss: 0.2711 - val_accuracy: 0.7021 - val_loss: 1.1737
# Epoch 26/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9195 - loss: 0.2599
# Epoch 26: val_accuracy did not improve from 0.82577
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 334ms/step - accuracy: 0.9195 - loss: 0.2599 - val_accuracy: 0.8155 - val_loss: 0.4949
# Epoch 27/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.9078 - loss: 0.2780
# Epoch 27: val_accuracy did not improve from 0.82577
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 323ms/step - accuracy: 0.9078 - loss: 0.2779 - val_accuracy: 0.6412 - val_loss: 1.9805
# Epoch 28/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.9315 - loss: 0.2137
# Epoch 28: val_accuracy did not improve from 0.82577
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 332ms/step - accuracy: 0.9314 - loss: 0.2138 - val_accuracy: 0.5598 - val_loss: 2.6586
# Epoch 28: early stopping
# Restoring model weights from the end of the best epoch: 18.
#
# Fold 1 - Validation Accuracy: 0.8258
#
# FOLD 2/5
# Building Stage 2 with 3 blocks, filters=64
#   ✅ Triplet Attention added at Stage 2
# Building Stage 3 with 4 blocks, filters=128
#   ✅ Triplet Attention added at Stage 3
# Building Stage 4 with 6 blocks, filters=256
#   ✅ Triplet Attention added at Stage 4
# Building Stage 5 with 3 blocks, filters=512
#   ✅ Triplet Attention added at Stage 5
# Epoch 1/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 800ms/step - accuracy: 0.3312 - loss: 1.8336
# Epoch 1: val_accuracy improved from -inf to 0.29072, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold2_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 207s 917ms/step - accuracy: 0.3316 - loss: 1.8306 - val_accuracy: 0.2907 - val_loss: 2.6274
# Epoch 2/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.4862 - loss: 1.1700
# Epoch 2: val_accuracy did not improve from 0.29072
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 325ms/step - accuracy: 0.4863 - loss: 1.1698 - val_accuracy: 0.2907 - val_loss: 8.1173
# Epoch 3/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.5488 - loss: 1.0552
# Epoch 3: val_accuracy did not improve from 0.29072
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 327ms/step - accuracy: 0.5489 - loss: 1.0550 - val_accuracy: 0.2784 - val_loss: 1.5246
# Epoch 4/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.5747 - loss: 0.9791
# Epoch 4: val_accuracy improved from 0.29072 to 0.58557, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold2_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 43s 348ms/step - accuracy: 0.5748 - loss: 0.9789 - val_accuracy: 0.5856 - val_loss: 1.1371
# Epoch 5/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.6136 - loss: 0.9158
# Epoch 5: val_accuracy did not improve from 0.58557
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 331ms/step - accuracy: 0.6137 - loss: 0.9156 - val_accuracy: 0.4866 - val_loss: 2.0168
# Epoch 6/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.6563 - loss: 0.8741
# Epoch 6: val_accuracy did not improve from 0.58557
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 339ms/step - accuracy: 0.6563 - loss: 0.8739 - val_accuracy: 0.5330 - val_loss: 1.8542
# Epoch 7/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.6796 - loss: 0.7926
# Epoch 7: val_accuracy did not improve from 0.58557
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 335ms/step - accuracy: 0.6796 - loss: 0.7926 - val_accuracy: 0.5371 - val_loss: 2.1365
# Epoch 8/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.7149 - loss: 0.7399
# Epoch 8: val_accuracy improved from 0.58557 to 0.60722, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold2_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 42s 341ms/step - accuracy: 0.7149 - loss: 0.7399 - val_accuracy: 0.6072 - val_loss: 1.3796
# Epoch 9/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.7499 - loss: 0.6798
# Epoch 9: val_accuracy did not improve from 0.60722
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 325ms/step - accuracy: 0.7498 - loss: 0.6799 - val_accuracy: 0.4835 - val_loss: 1.3526
# Epoch 10/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.7537 - loss: 0.6446
# Epoch 10: val_accuracy did not improve from 0.60722
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 326ms/step - accuracy: 0.7538 - loss: 0.6446 - val_accuracy: 0.4825 - val_loss: 2.2548
# Epoch 11/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.7813 - loss: 0.5952
# Epoch 11: val_accuracy improved from 0.60722 to 0.62474, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold2_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 42s 339ms/step - accuracy: 0.7813 - loss: 0.5952 - val_accuracy: 0.6247 - val_loss: 1.1278
# Epoch 12/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.8129 - loss: 0.5604
# Epoch 12: val_accuracy did not improve from 0.62474
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 325ms/step - accuracy: 0.8130 - loss: 0.5602 - val_accuracy: 0.4804 - val_loss: 2.6146
# Epoch 13/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.8418 - loss: 0.4918
# Epoch 13: val_accuracy did not improve from 0.62474
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 325ms/step - accuracy: 0.8417 - loss: 0.4918 - val_accuracy: 0.4722 - val_loss: 2.2919
# Epoch 14/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.8146 - loss: 0.5191
# Epoch 14: val_accuracy improved from 0.62474 to 0.69278, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold2_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 42s 342ms/step - accuracy: 0.8146 - loss: 0.5192 - val_accuracy: 0.6928 - val_loss: 1.0961
# Epoch 15/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.8464 - loss: 0.4549
# Epoch 15: val_accuracy did not improve from 0.69278
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 325ms/step - accuracy: 0.8464 - loss: 0.4549 - val_accuracy: 0.6773 - val_loss: 1.1034
# Epoch 16/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.8605 - loss: 0.4064
# Epoch 16: val_accuracy did not improve from 0.69278
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 329ms/step - accuracy: 0.8605 - loss: 0.4066 - val_accuracy: 0.5629 - val_loss: 1.8880
# Epoch 17/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - accuracy: 0.8692 - loss: 0.3865
# Epoch 17: val_accuracy did not improve from 0.69278
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 322ms/step - accuracy: 0.8692 - loss: 0.3865 - val_accuracy: 0.6773 - val_loss: 1.2299
# Epoch 18/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.8875 - loss: 0.3470
# Epoch 18: val_accuracy did not improve from 0.69278
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 328ms/step - accuracy: 0.8874 - loss: 0.3471 - val_accuracy: 0.5536 - val_loss: 1.6071
# Epoch 19/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - accuracy: 0.8888 - loss: 0.3227
# Epoch 19: val_accuracy improved from 0.69278 to 0.81753, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold2_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 337ms/step - accuracy: 0.8888 - loss: 0.3228 - val_accuracy: 0.8175 - val_loss: 0.4924
# Epoch 20/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.8999 - loss: 0.2844
# Epoch 20: val_accuracy did not improve from 0.81753
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 334ms/step - accuracy: 0.8998 - loss: 0.2848 - val_accuracy: 0.6000 - val_loss: 1.5289
# Epoch 21/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.8969 - loss: 0.3057
# Epoch 21: val_accuracy did not improve from 0.81753
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 329ms/step - accuracy: 0.8969 - loss: 0.3058 - val_accuracy: 0.3443 - val_loss: 5.1860
# Epoch 22/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 0.9056 - loss: 0.2953
# Epoch 22: val_accuracy did not improve from 0.81753
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 324ms/step - accuracy: 0.9056 - loss: 0.2954 - val_accuracy: 0.4351 - val_loss: 3.5678
# Epoch 23/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - accuracy: 0.8957 - loss: 0.3145
# Epoch 23: val_accuracy did not improve from 0.81753
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 39s 322ms/step - accuracy: 0.8957 - loss: 0.3144 - val_accuracy: 0.7464 - val_loss: 0.8131
# Epoch 24/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.9211 - loss: 0.2691
# Epoch 24: val_accuracy did not improve from 0.81753
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 326ms/step - accuracy: 0.9210 - loss: 0.2693 - val_accuracy: 0.6959 - val_loss: 0.9561
# Epoch 25/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.9184 - loss: 0.2624
# Epoch 25: val_accuracy did not improve from 0.81753
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 42s 340ms/step - accuracy: 0.9184 - loss: 0.2623 - val_accuracy: 0.6412 - val_loss: 1.3207
# Epoch 26/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.9222 - loss: 0.2276
# Epoch 26: val_accuracy did not improve from 0.81753
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 335ms/step - accuracy: 0.9222 - loss: 0.2278 - val_accuracy: 0.5258 - val_loss: 1.8722
# Epoch 27/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.9210 - loss: 0.2383
# Epoch 27: val_accuracy did not improve from 0.81753
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 326ms/step - accuracy: 0.9211 - loss: 0.2382 - val_accuracy: 0.6588 - val_loss: 1.1201
# Epoch 28/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9364 - loss: 0.1885
# Epoch 28: val_accuracy did not improve from 0.81753
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 328ms/step - accuracy: 0.9363 - loss: 0.1886 - val_accuracy: 0.3155 - val_loss: 7.1700
# Epoch 29/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.9278 - loss: 0.2173
# Epoch 29: val_accuracy did not improve from 0.81753
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 323ms/step - accuracy: 0.9277 - loss: 0.2174 - val_accuracy: 0.7495 - val_loss: 0.7261
# Epoch 29: early stopping
# Restoring model weights from the end of the best epoch: 19.
#
# Fold 2 - Validation Accuracy: 0.8175
#
# FOLD 3/5
# Building Stage 2 with 3 blocks, filters=64
#   ✅ Triplet Attention added at Stage 2
# Building Stage 3 with 4 blocks, filters=128
#   ✅ Triplet Attention added at Stage 3
# Building Stage 4 with 6 blocks, filters=256
#   ✅ Triplet Attention added at Stage 4
# Building Stage 5 with 3 blocks, filters=512
#   ✅ Triplet Attention added at Stage 5
# Epoch 1/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 796ms/step - accuracy: 0.3880 - loss: 1.6068
# Epoch 1: val_accuracy improved from -inf to 0.29175, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold3_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 207s 912ms/step - accuracy: 0.3884 - loss: 1.6050 - val_accuracy: 0.2918 - val_loss: 1.8560
# Epoch 2/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.5086 - loss: 1.1513
# Epoch 2: val_accuracy did not improve from 0.29175
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 335ms/step - accuracy: 0.5087 - loss: 1.1511 - val_accuracy: 0.2918 - val_loss: 3.3449
# Epoch 3/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.5590 - loss: 1.0210
# Epoch 3: val_accuracy improved from 0.29175 to 0.30928, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold3_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 42s 339ms/step - accuracy: 0.5591 - loss: 1.0208 - val_accuracy: 0.3093 - val_loss: 3.3307
# Epoch 4/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.6014 - loss: 0.9777
# Epoch 4: val_accuracy improved from 0.30928 to 0.59588, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold3_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 42s 343ms/step - accuracy: 0.6013 - loss: 0.9775 - val_accuracy: 0.5959 - val_loss: 1.0314
# Epoch 5/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.6298 - loss: 0.9049
# Epoch 5: val_accuracy did not improve from 0.59588
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 336ms/step - accuracy: 0.6298 - loss: 0.9048 - val_accuracy: 0.4237 - val_loss: 1.9795
# Epoch 6/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.6343 - loss: 0.8538
# Epoch 6: val_accuracy did not improve from 0.59588
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 329ms/step - accuracy: 0.6343 - loss: 0.8537 - val_accuracy: 0.5763 - val_loss: 1.5080
# Epoch 7/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.6685 - loss: 0.8294
# Epoch 7: val_accuracy did not improve from 0.59588
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 331ms/step - accuracy: 0.6685 - loss: 0.8292 - val_accuracy: 0.5691 - val_loss: 0.9595
# Epoch 8/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.6706 - loss: 0.8430
# Epoch 8: val_accuracy did not improve from 0.59588
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 326ms/step - accuracy: 0.6706 - loss: 0.8429 - val_accuracy: 0.4928 - val_loss: 1.1398
# Epoch 9/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.7022 - loss: 0.7763
# Epoch 9: val_accuracy did not improve from 0.59588
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 327ms/step - accuracy: 0.7023 - loss: 0.7760 - val_accuracy: 0.2990 - val_loss: 4.7170
# Epoch 10/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.7342 - loss: 0.6981
# Epoch 10: val_accuracy improved from 0.59588 to 0.68969, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold3_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 42s 340ms/step - accuracy: 0.7341 - loss: 0.6982 - val_accuracy: 0.6897 - val_loss: 0.8524
# Epoch 11/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.7427 - loss: 0.6856
# Epoch 11: val_accuracy did not improve from 0.68969
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 328ms/step - accuracy: 0.7427 - loss: 0.6855 - val_accuracy: 0.4443 - val_loss: 3.9763
# Epoch 12/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.7594 - loss: 0.6474
# Epoch 12: val_accuracy did not improve from 0.68969
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 323ms/step - accuracy: 0.7594 - loss: 0.6473 - val_accuracy: 0.5577 - val_loss: 1.6493
# Epoch 13/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 0.7807 - loss: 0.5803
# Epoch 13: val_accuracy did not improve from 0.68969
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 324ms/step - accuracy: 0.7807 - loss: 0.5804 - val_accuracy: 0.3577 - val_loss: 4.4163
# Epoch 14/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.7953 - loss: 0.5586
# Epoch 14: val_accuracy improved from 0.68969 to 0.69485, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold3_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 43s 350ms/step - accuracy: 0.7953 - loss: 0.5584 - val_accuracy: 0.6948 - val_loss: 0.8455
# Epoch 15/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.8312 - loss: 0.4697
# Epoch 15: val_accuracy did not improve from 0.69485
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 42s 340ms/step - accuracy: 0.8312 - loss: 0.4698 - val_accuracy: 0.6711 - val_loss: 0.9668
# Epoch 16/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.8428 - loss: 0.4637
# Epoch 16: val_accuracy improved from 0.69485 to 0.69588, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold3_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 42s 346ms/step - accuracy: 0.8428 - loss: 0.4636 - val_accuracy: 0.6959 - val_loss: 1.3056
# Epoch 17/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.8452 - loss: 0.4428
# Epoch 17: val_accuracy did not improve from 0.69588
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 331ms/step - accuracy: 0.8452 - loss: 0.4427 - val_accuracy: 0.6268 - val_loss: 1.0396
# Epoch 18/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.8561 - loss: 0.4098
# Epoch 18: val_accuracy did not improve from 0.69588
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 332ms/step - accuracy: 0.8562 - loss: 0.4097 - val_accuracy: 0.5577 - val_loss: 1.8320
# Epoch 19/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.8685 - loss: 0.3912
# Epoch 19: val_accuracy improved from 0.69588 to 0.70309, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold3_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 42s 340ms/step - accuracy: 0.8685 - loss: 0.3911 - val_accuracy: 0.7031 - val_loss: 0.8639
# Epoch 20/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.8677 - loss: 0.3958
# Epoch 20: val_accuracy did not improve from 0.70309
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 331ms/step - accuracy: 0.8678 - loss: 0.3957 - val_accuracy: 0.6619 - val_loss: 1.0251
# Epoch 21/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.8724 - loss: 0.3716
# Epoch 21: val_accuracy did not improve from 0.70309
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 326ms/step - accuracy: 0.8724 - loss: 0.3716 - val_accuracy: 0.6041 - val_loss: 2.3945
# Epoch 22/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.8823 - loss: 0.3318
# Epoch 22: val_accuracy did not improve from 0.70309
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 334ms/step - accuracy: 0.8823 - loss: 0.3319 - val_accuracy: 0.4938 - val_loss: 1.7422
# Epoch 23/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.8984 - loss: 0.3243
# Epoch 23: val_accuracy did not improve from 0.70309
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 326ms/step - accuracy: 0.8984 - loss: 0.3242 - val_accuracy: 0.6845 - val_loss: 1.0400
# Epoch 24/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.8919 - loss: 0.3103
# Epoch 24: val_accuracy improved from 0.70309 to 0.72268, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold3_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 43s 349ms/step - accuracy: 0.8920 - loss: 0.3103 - val_accuracy: 0.7227 - val_loss: 0.9118
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 14.
#
# Fold 3 - Validation Accuracy: 0.6948
#
# FOLD 4/5
# Building Stage 2 with 3 blocks, filters=64
#   ✅ Triplet Attention added at Stage 2
# Building Stage 3 with 4 blocks, filters=128
#   ✅ Triplet Attention added at Stage 3
# Building Stage 4 with 6 blocks, filters=256
#   ✅ Triplet Attention added at Stage 4
# Building Stage 5 with 3 blocks, filters=512
#   ✅ Triplet Attention added at Stage 5
# Epoch 1/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 857ms/step - accuracy: 0.3879 - loss: 1.4012
# Epoch 1: val_accuracy improved from -inf to 0.29102, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold4_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 218s 1s/step - accuracy: 0.3884 - loss: 1.4001 - val_accuracy: 0.2910 - val_loss: 7.4097
# Epoch 2/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.5202 - loss: 1.1266
# Epoch 2: val_accuracy did not improve from 0.29102
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 336ms/step - accuracy: 0.5204 - loss: 1.1263 - val_accuracy: 0.2621 - val_loss: 2.5677
# Epoch 3/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 0.6213 - loss: 0.9523
# Epoch 3: val_accuracy improved from 0.29102 to 0.31269, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold4_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 338ms/step - accuracy: 0.6213 - loss: 0.9523 - val_accuracy: 0.3127 - val_loss: 6.4253
# Epoch 4/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.6536 - loss: 0.8774
# Epoch 4: val_accuracy improved from 0.31269 to 0.48091, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold4_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 42s 345ms/step - accuracy: 0.6537 - loss: 0.8773 - val_accuracy: 0.4809 - val_loss: 1.5669
# Epoch 5/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.7101 - loss: 0.7542
# Epoch 5: val_accuracy did not improve from 0.48091
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 330ms/step - accuracy: 0.7102 - loss: 0.7542 - val_accuracy: 0.4788 - val_loss: 2.5500
# Epoch 6/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.7444 - loss: 0.6684
# Epoch 6: val_accuracy improved from 0.48091 to 0.50464, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold4_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 42s 345ms/step - accuracy: 0.7444 - loss: 0.6685 - val_accuracy: 0.5046 - val_loss: 2.4847
# Epoch 7/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.7755 - loss: 0.6066
# Epoch 7: val_accuracy improved from 0.50464 to 0.68215, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold4_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 43s 348ms/step - accuracy: 0.7755 - loss: 0.6067 - val_accuracy: 0.6821 - val_loss: 1.0802
# Epoch 8/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.7851 - loss: 0.6112
# Epoch 8: val_accuracy improved from 0.68215 to 0.70588, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold4_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 43s 349ms/step - accuracy: 0.7851 - loss: 0.6110 - val_accuracy: 0.7059 - val_loss: 0.8624
# Epoch 9/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.8008 - loss: 0.5673
# Epoch 9: val_accuracy did not improve from 0.70588
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 326ms/step - accuracy: 0.8008 - loss: 0.5672 - val_accuracy: 0.6729 - val_loss: 0.8483
# Epoch 10/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.8178 - loss: 0.5190
# Epoch 10: val_accuracy did not improve from 0.70588
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 328ms/step - accuracy: 0.8178 - loss: 0.5189 - val_accuracy: 0.6935 - val_loss: 1.0162
# Epoch 11/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.8375 - loss: 0.4747
# Epoch 11: val_accuracy improved from 0.70588 to 0.72239, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold4_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 42s 344ms/step - accuracy: 0.8375 - loss: 0.4748 - val_accuracy: 0.7224 - val_loss: 0.7943
# Epoch 12/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.8432 - loss: 0.4303
# Epoch 12: val_accuracy did not improve from 0.72239
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 335ms/step - accuracy: 0.8432 - loss: 0.4305 - val_accuracy: 0.5986 - val_loss: 1.6182
# Epoch 13/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.8546 - loss: 0.4155
# Epoch 13: val_accuracy did not improve from 0.72239
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 329ms/step - accuracy: 0.8545 - loss: 0.4157 - val_accuracy: 0.6625 - val_loss: 1.0985
# Epoch 14/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - accuracy: 0.8624 - loss: 0.4012
# Epoch 14: val_accuracy improved from 0.72239 to 0.76780, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold4_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 337ms/step - accuracy: 0.8624 - loss: 0.4011 - val_accuracy: 0.7678 - val_loss: 0.6449
# Epoch 15/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.8691 - loss: 0.3805
# Epoch 15: val_accuracy improved from 0.76780 to 0.80599, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold4_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 42s 346ms/step - accuracy: 0.8690 - loss: 0.3805 - val_accuracy: 0.8060 - val_loss: 0.6364
# Epoch 16/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.8682 - loss: 0.3957
# Epoch 16: val_accuracy did not improve from 0.80599
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 331ms/step - accuracy: 0.8682 - loss: 0.3956 - val_accuracy: 0.4727 - val_loss: 3.7193
# Epoch 17/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.8845 - loss: 0.3359
# Epoch 17: val_accuracy improved from 0.80599 to 0.82559, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold4_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 42s 343ms/step - accuracy: 0.8845 - loss: 0.3359 - val_accuracy: 0.8256 - val_loss: 0.5105
# Epoch 18/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.8893 - loss: 0.3321
# Epoch 18: val_accuracy did not improve from 0.82559
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 338ms/step - accuracy: 0.8893 - loss: 0.3322 - val_accuracy: 0.4985 - val_loss: 4.8993
# Epoch 19/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.8868 - loss: 0.3286
# Epoch 19: val_accuracy did not improve from 0.82559
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 330ms/step - accuracy: 0.8868 - loss: 0.3286 - val_accuracy: 0.7657 - val_loss: 0.8005
# Epoch 20/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.8979 - loss: 0.2999
# Epoch 20: val_accuracy did not improve from 0.82559
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 334ms/step - accuracy: 0.8978 - loss: 0.3001 - val_accuracy: 0.7884 - val_loss: 1.0256
# Epoch 21/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 0.9013 - loss: 0.2803
# Epoch 21: val_accuracy did not improve from 0.82559
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 324ms/step - accuracy: 0.9013 - loss: 0.2805 - val_accuracy: 0.7503 - val_loss: 0.8560
# Epoch 22/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.8744 - loss: 0.3512
# Epoch 22: val_accuracy did not improve from 0.82559
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 327ms/step - accuracy: 0.8745 - loss: 0.3509 - val_accuracy: 0.6883 - val_loss: 1.8922
# Epoch 23/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.9080 - loss: 0.2694
# Epoch 23: val_accuracy did not improve from 0.82559
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 330ms/step - accuracy: 0.9080 - loss: 0.2694 - val_accuracy: 0.7822 - val_loss: 0.8986
# Epoch 24/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.8929 - loss: 0.3007
# Epoch 24: val_accuracy did not improve from 0.82559
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 330ms/step - accuracy: 0.8930 - loss: 0.3006 - val_accuracy: 0.7503 - val_loss: 0.7071
# Epoch 25/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.9206 - loss: 0.2446
# Epoch 25: val_accuracy did not improve from 0.82559
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 327ms/step - accuracy: 0.9206 - loss: 0.2446 - val_accuracy: 0.7245 - val_loss: 1.2185
# Epoch 26/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.9033 - loss: 0.2700
# Epoch 26: val_accuracy did not improve from 0.82559
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 331ms/step - accuracy: 0.9034 - loss: 0.2699 - val_accuracy: 0.6285 - val_loss: 1.3952
# Epoch 27/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.9219 - loss: 0.2383
# Epoch 27: val_accuracy improved from 0.82559 to 0.84727, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold4_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 42s 344ms/step - accuracy: 0.9219 - loss: 0.2383 - val_accuracy: 0.8473 - val_loss: 0.4072
# Epoch 28/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.9282 - loss: 0.2067
# Epoch 28: val_accuracy did not improve from 0.84727
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 330ms/step - accuracy: 0.9282 - loss: 0.2068 - val_accuracy: 0.7523 - val_loss: 0.8467
# Epoch 29/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.9134 - loss: 0.2505
# Epoch 29: val_accuracy did not improve from 0.84727
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 332ms/step - accuracy: 0.9135 - loss: 0.2504 - val_accuracy: 0.8421 - val_loss: 0.5149
# Epoch 30/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 0.9298 - loss: 0.1966
# Epoch 30: val_accuracy improved from 0.84727 to 0.85139, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold4_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 339ms/step - accuracy: 0.9298 - loss: 0.1966 - val_accuracy: 0.8514 - val_loss: 0.5729
# Epoch 31/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.9347 - loss: 0.1914
# Epoch 31: val_accuracy improved from 0.85139 to 0.85243, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold4_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 43s 352ms/step - accuracy: 0.9347 - loss: 0.1914 - val_accuracy: 0.8524 - val_loss: 0.4964
# Epoch 32/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.9342 - loss: 0.2164
# Epoch 32: val_accuracy improved from 0.85243 to 0.87203, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold4_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 43s 353ms/step - accuracy: 0.9342 - loss: 0.2165 - val_accuracy: 0.8720 - val_loss: 0.3675
# Epoch 33/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.9281 - loss: 0.2134
# Epoch 33: val_accuracy did not improve from 0.87203
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 331ms/step - accuracy: 0.9282 - loss: 0.2133 - val_accuracy: 0.5315 - val_loss: 2.3325
# Epoch 34/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 0.9353 - loss: 0.2118
# Epoch 34: val_accuracy improved from 0.87203 to 0.88854, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold4_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 338ms/step - accuracy: 0.9353 - loss: 0.2117 - val_accuracy: 0.8885 - val_loss: 0.3722
# Epoch 35/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.9375 - loss: 0.1924
# Epoch 35: val_accuracy improved from 0.88854 to 0.89886, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold4_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 43s 347ms/step - accuracy: 0.9375 - loss: 0.1924 - val_accuracy: 0.8989 - val_loss: 0.3111
# Epoch 36/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.9455 - loss: 0.1621
# Epoch 36: val_accuracy did not improve from 0.89886
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 330ms/step - accuracy: 0.9455 - loss: 0.1621 - val_accuracy: 0.7802 - val_loss: 0.7877
# Epoch 37/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.9461 - loss: 0.1637
# Epoch 37: val_accuracy did not improve from 0.89886
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 327ms/step - accuracy: 0.9460 - loss: 0.1639 - val_accuracy: 0.7771 - val_loss: 0.6411
# Epoch 38/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.9421 - loss: 0.2024
# Epoch 38: val_accuracy did not improve from 0.89886
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 329ms/step - accuracy: 0.9422 - loss: 0.2021 - val_accuracy: 0.8318 - val_loss: 0.6646
# Epoch 39/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 0.9328 - loss: 0.2000
# Epoch 39: val_accuracy did not improve from 0.89886
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 325ms/step - accuracy: 0.9327 - loss: 0.2001 - val_accuracy: 0.7595 - val_loss: 0.8339
# Epoch 40/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.9366 - loss: 0.1857
# Epoch 40: val_accuracy did not improve from 0.89886
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 326ms/step - accuracy: 0.9366 - loss: 0.1857 - val_accuracy: 0.8772 - val_loss: 0.3773
# Epoch 41/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.9409 - loss: 0.1767
# Epoch 41: val_accuracy did not improve from 0.89886
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 325ms/step - accuracy: 0.9409 - loss: 0.1766 - val_accuracy: 0.8720 - val_loss: 0.3230
# Epoch 42/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.9558 - loss: 0.1391
# Epoch 42: val_accuracy did not improve from 0.89886
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 329ms/step - accuracy: 0.9557 - loss: 0.1392 - val_accuracy: 0.8689 - val_loss: 0.4578
# Epoch 43/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.9450 - loss: 0.1450
# Epoch 43: val_accuracy improved from 0.89886 to 0.91331, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold4_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 42s 345ms/step - accuracy: 0.9451 - loss: 0.1450 - val_accuracy: 0.9133 - val_loss: 0.3563
# Epoch 44/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.9462 - loss: 0.1766
# Epoch 44: val_accuracy did not improve from 0.91331
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 333ms/step - accuracy: 0.9462 - loss: 0.1766 - val_accuracy: 0.8927 - val_loss: 0.3025
# Epoch 45/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.9596 - loss: 0.1355
# Epoch 45: val_accuracy did not improve from 0.91331
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 334ms/step - accuracy: 0.9596 - loss: 0.1355 - val_accuracy: 0.8989 - val_loss: 0.2697
# Epoch 46/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9451 - loss: 0.1730
# Epoch 46: val_accuracy did not improve from 0.91331
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 328ms/step - accuracy: 0.9451 - loss: 0.1730 - val_accuracy: 0.8029 - val_loss: 0.6234
# Epoch 47/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9506 - loss: 0.1474
# Epoch 47: val_accuracy did not improve from 0.91331
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 328ms/step - accuracy: 0.9506 - loss: 0.1474 - val_accuracy: 0.9123 - val_loss: 0.2957
# Epoch 48/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.9563 - loss: 0.1262
# Epoch 48: val_accuracy improved from 0.91331 to 0.92570, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold4_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 42s 339ms/step - accuracy: 0.9563 - loss: 0.1263 - val_accuracy: 0.9257 - val_loss: 0.3273
# Epoch 49/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.9664 - loss: 0.0947
# Epoch 49: val_accuracy did not improve from 0.92570
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 336ms/step - accuracy: 0.9663 - loss: 0.0948 - val_accuracy: 0.8896 - val_loss: 0.4071
# Epoch 50/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 0.9584 - loss: 0.1200
# Epoch 50: val_accuracy did not improve from 0.92570
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 325ms/step - accuracy: 0.9584 - loss: 0.1201 - val_accuracy: 0.9133 - val_loss: 0.2431
# Epoch 51/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.9518 - loss: 0.1390
# Epoch 51: val_accuracy did not improve from 0.92570
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 329ms/step - accuracy: 0.9518 - loss: 0.1390 - val_accuracy: 0.7730 - val_loss: 0.8325
# Epoch 52/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.9570 - loss: 0.1151
# Epoch 52: val_accuracy did not improve from 0.92570
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 327ms/step - accuracy: 0.9570 - loss: 0.1151 - val_accuracy: 0.8122 - val_loss: 0.6749
# Epoch 53/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.9598 - loss: 0.1124
# Epoch 53: val_accuracy did not improve from 0.92570
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 326ms/step - accuracy: 0.9598 - loss: 0.1125 - val_accuracy: 0.7131 - val_loss: 0.9409
# Epoch 54/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 0.9672 - loss: 0.1038
# Epoch 54: val_accuracy did not improve from 0.92570
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 324ms/step - accuracy: 0.9672 - loss: 0.1038 - val_accuracy: 0.8741 - val_loss: 0.4044
# Epoch 55/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.9611 - loss: 0.1255
# Epoch 55: val_accuracy did not improve from 0.92570
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 326ms/step - accuracy: 0.9611 - loss: 0.1255 - val_accuracy: 0.8762 - val_loss: 0.4374
# Epoch 56/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.9487 - loss: 0.1649
# Epoch 56: val_accuracy did not improve from 0.92570
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 329ms/step - accuracy: 0.9487 - loss: 0.1647 - val_accuracy: 0.8163 - val_loss: 0.5254
# Epoch 57/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.9666 - loss: 0.1001
# Epoch 57: val_accuracy did not improve from 0.92570
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 325ms/step - accuracy: 0.9666 - loss: 0.1001 - val_accuracy: 0.7430 - val_loss: 1.2540
# Epoch 58/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.9531 - loss: 0.1385
# Epoch 58: val_accuracy did not improve from 0.92570
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 327ms/step - accuracy: 0.9531 - loss: 0.1384 - val_accuracy: 0.8504 - val_loss: 0.5149
# Epoch 59/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.9539 - loss: 0.1202
# Epoch 59: val_accuracy improved from 0.92570 to 0.93911, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold4_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 42s 341ms/step - accuracy: 0.9540 - loss: 0.1202 - val_accuracy: 0.9391 - val_loss: 0.1896
# Epoch 60/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.9723 - loss: 0.1027
# Epoch 60: val_accuracy did not improve from 0.93911
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 330ms/step - accuracy: 0.9723 - loss: 0.1027 - val_accuracy: 0.8916 - val_loss: 0.4432
# Epoch 61/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 0.9767 - loss: 0.0790
# Epoch 61: val_accuracy did not improve from 0.93911
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 324ms/step - accuracy: 0.9767 - loss: 0.0791 - val_accuracy: 0.8504 - val_loss: 0.5991
# Epoch 62/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.9697 - loss: 0.0830
# Epoch 62: val_accuracy did not improve from 0.93911
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 330ms/step - accuracy: 0.9697 - loss: 0.0832 - val_accuracy: 0.8782 - val_loss: 0.4720
# Epoch 63/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.9626 - loss: 0.1239
# Epoch 63: val_accuracy did not improve from 0.93911
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 326ms/step - accuracy: 0.9626 - loss: 0.1237 - val_accuracy: 0.8266 - val_loss: 0.8076
# Epoch 64/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.9728 - loss: 0.0874
# Epoch 64: val_accuracy did not improve from 0.93911
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 327ms/step - accuracy: 0.9728 - loss: 0.0875 - val_accuracy: 0.9350 - val_loss: 0.1961
# Epoch 65/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.9654 - loss: 0.1030
# Epoch 65: val_accuracy did not improve from 0.93911
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 338ms/step - accuracy: 0.9654 - loss: 0.1031 - val_accuracy: 0.9082 - val_loss: 0.2996
# Epoch 66/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.9528 - loss: 0.1514
# Epoch 66: val_accuracy did not improve from 0.93911
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 333ms/step - accuracy: 0.9529 - loss: 0.1511 - val_accuracy: 0.8184 - val_loss: 0.7543
# Epoch 67/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.9661 - loss: 0.0854
# Epoch 67: val_accuracy did not improve from 0.93911
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 330ms/step - accuracy: 0.9660 - loss: 0.0855 - val_accuracy: 0.5191 - val_loss: 1.9774
# Epoch 68/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.9622 - loss: 0.1132
# Epoch 68: val_accuracy did not improve from 0.93911
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 331ms/step - accuracy: 0.9623 - loss: 0.1131 - val_accuracy: 0.9226 - val_loss: 0.2466
# Epoch 69/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.9698 - loss: 0.0822
# Epoch 69: val_accuracy did not improve from 0.93911
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 336ms/step - accuracy: 0.9697 - loss: 0.0825 - val_accuracy: 0.8937 - val_loss: 0.3851
# Epoch 69: early stopping
# Restoring model weights from the end of the best epoch: 59.
#
# Fold 4 - Validation Accuracy: 0.9391
#
# FOLD 5/5
# Building Stage 2 with 3 blocks, filters=64
#   ✅ Triplet Attention added at Stage 2
# Building Stage 3 with 4 blocks, filters=128
#   ✅ Triplet Attention added at Stage 3
# Building Stage 4 with 6 blocks, filters=256
#   ✅ Triplet Attention added at Stage 4
# Building Stage 5 with 3 blocks, filters=512
#   ✅ Triplet Attention added at Stage 5
# Epoch 1/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 807ms/step - accuracy: 0.3663 - loss: 1.6472
# Epoch 1: val_accuracy improved from -inf to 0.29102, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold5_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 207s 921ms/step - accuracy: 0.3667 - loss: 1.6451 - val_accuracy: 0.2910 - val_loss: 1.5832
# Epoch 2/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.4794 - loss: 1.1673
# Epoch 2: val_accuracy did not improve from 0.29102
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 331ms/step - accuracy: 0.4796 - loss: 1.1671 - val_accuracy: 0.2910 - val_loss: 4.9845
# Epoch 3/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.5105 - loss: 1.1021
# Epoch 3: val_accuracy improved from 0.29102 to 0.29825, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold5_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 42s 343ms/step - accuracy: 0.5108 - loss: 1.1017 - val_accuracy: 0.2982 - val_loss: 4.1856
# Epoch 4/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.5813 - loss: 0.9864
# Epoch 4: val_accuracy improved from 0.29825 to 0.56347, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold5_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 42s 344ms/step - accuracy: 0.5814 - loss: 0.9862 - val_accuracy: 0.5635 - val_loss: 1.3211
# Epoch 5/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.6407 - loss: 0.8773
# Epoch 5: val_accuracy improved from 0.56347 to 0.60888, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold5_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 42s 340ms/step - accuracy: 0.6407 - loss: 0.8773 - val_accuracy: 0.6089 - val_loss: 1.1154
# Epoch 6/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.6831 - loss: 0.8009
# Epoch 6: val_accuracy improved from 0.60888 to 0.63777, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold5_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 43s 348ms/step - accuracy: 0.6831 - loss: 0.8010 - val_accuracy: 0.6378 - val_loss: 0.9453
# Epoch 7/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.7255 - loss: 0.7085
# Epoch 7: val_accuracy did not improve from 0.63777
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 327ms/step - accuracy: 0.7254 - loss: 0.7086 - val_accuracy: 0.5304 - val_loss: 1.6884
# Epoch 8/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.7519 - loss: 0.6946
# Epoch 8: val_accuracy did not improve from 0.63777
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 332ms/step - accuracy: 0.7520 - loss: 0.6943 - val_accuracy: 0.5717 - val_loss: 1.3289
# Epoch 9/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.7697 - loss: 0.6161
# Epoch 9: val_accuracy improved from 0.63777 to 0.69659, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold5_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 42s 343ms/step - accuracy: 0.7697 - loss: 0.6161 - val_accuracy: 0.6966 - val_loss: 0.8704
# Epoch 10/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.7842 - loss: 0.5847
# Epoch 10: val_accuracy did not improve from 0.69659
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 330ms/step - accuracy: 0.7843 - loss: 0.5846 - val_accuracy: 0.5212 - val_loss: 1.3398
# Epoch 11/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.8028 - loss: 0.5468
# Epoch 11: val_accuracy did not improve from 0.69659
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 328ms/step - accuracy: 0.8028 - loss: 0.5467 - val_accuracy: 0.5934 - val_loss: 1.8114
# Epoch 12/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.8219 - loss: 0.4819
# Epoch 12: val_accuracy did not improve from 0.69659
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 324ms/step - accuracy: 0.8220 - loss: 0.4818 - val_accuracy: 0.5490 - val_loss: 1.6485
# Epoch 13/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.8295 - loss: 0.4764
# Epoch 13: val_accuracy improved from 0.69659 to 0.73994, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold5_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 42s 339ms/step - accuracy: 0.8295 - loss: 0.4764 - val_accuracy: 0.7399 - val_loss: 0.8914
# Epoch 14/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.8669 - loss: 0.3966
# Epoch 14: val_accuracy improved from 0.73994 to 0.75851, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold5_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 42s 343ms/step - accuracy: 0.8668 - loss: 0.3968 - val_accuracy: 0.7585 - val_loss: 0.8776
# Epoch 15/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.8673 - loss: 0.3918
# Epoch 15: val_accuracy did not improve from 0.75851
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 334ms/step - accuracy: 0.8673 - loss: 0.3917 - val_accuracy: 0.6512 - val_loss: 0.9725
# Epoch 16/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.8685 - loss: 0.3829
# Epoch 16: val_accuracy did not improve from 0.75851
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 326ms/step - accuracy: 0.8684 - loss: 0.3829 - val_accuracy: 0.6419 - val_loss: 1.7859
# Epoch 17/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.8965 - loss: 0.3247
# Epoch 17: val_accuracy improved from 0.75851 to 0.78431, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold5_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 338ms/step - accuracy: 0.8964 - loss: 0.3248 - val_accuracy: 0.7843 - val_loss: 0.6560
# Epoch 18/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.9035 - loss: 0.2932
# Epoch 18: val_accuracy did not improve from 0.78431
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 333ms/step - accuracy: 0.9035 - loss: 0.2935 - val_accuracy: 0.7554 - val_loss: 0.7052
# Epoch 19/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.9117 - loss: 0.2904
# Epoch 19: val_accuracy did not improve from 0.78431
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 325ms/step - accuracy: 0.9116 - loss: 0.2904 - val_accuracy: 0.7688 - val_loss: 0.9106
# Epoch 20/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.9016 - loss: 0.2910
# Epoch 20: val_accuracy did not improve from 0.78431
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 323ms/step - accuracy: 0.9015 - loss: 0.2911 - val_accuracy: 0.7843 - val_loss: 0.8464
# Epoch 21/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.9203 - loss: 0.2480
# Epoch 21: val_accuracy did not improve from 0.78431
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 337ms/step - accuracy: 0.9202 - loss: 0.2481 - val_accuracy: 0.1981 - val_loss: 5.2089
# Epoch 22/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.7779 - loss: 0.5858
# Epoch 22: val_accuracy improved from 0.78431 to 0.86687, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold5_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 43s 348ms/step - accuracy: 0.7785 - loss: 0.5846 - val_accuracy: 0.8669 - val_loss: 0.5722
# Epoch 23/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9142 - loss: 0.2560
# Epoch 23: val_accuracy did not improve from 0.86687
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 328ms/step - accuracy: 0.9142 - loss: 0.2561 - val_accuracy: 0.5779 - val_loss: 2.1734
# Epoch 24/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.9349 - loss: 0.2150
# Epoch 24: val_accuracy did not improve from 0.86687
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 331ms/step - accuracy: 0.9348 - loss: 0.2151 - val_accuracy: 0.7482 - val_loss: 1.0944
# Epoch 25/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.9303 - loss: 0.2158
# Epoch 25: val_accuracy did not improve from 0.86687
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 330ms/step - accuracy: 0.9303 - loss: 0.2159 - val_accuracy: 0.7214 - val_loss: 0.8324
# Epoch 26/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.9275 - loss: 0.2119
# Epoch 26: val_accuracy did not improve from 0.86687
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 330ms/step - accuracy: 0.9275 - loss: 0.2119 - val_accuracy: 0.4324 - val_loss: 5.4677
# Epoch 27/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9309 - loss: 0.2130
# Epoch 27: val_accuracy did not improve from 0.86687
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 336ms/step - accuracy: 0.9310 - loss: 0.2129 - val_accuracy: 0.8669 - val_loss: 0.4328
# Epoch 28/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.9414 - loss: 0.1870
# Epoch 28: val_accuracy improved from 0.86687 to 0.91434, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold5_best.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 42s 345ms/step - accuracy: 0.9415 - loss: 0.1869 - val_accuracy: 0.9143 - val_loss: 0.2784
# Epoch 29/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9414 - loss: 0.1860
# Epoch 29: val_accuracy did not improve from 0.91434
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 334ms/step - accuracy: 0.9413 - loss: 0.1863 - val_accuracy: 0.6760 - val_loss: 0.9450
# Epoch 30/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.9210 - loss: 0.2596
# Epoch 30: val_accuracy did not improve from 0.91434
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 333ms/step - accuracy: 0.9210 - loss: 0.2594 - val_accuracy: 0.7018 - val_loss: 0.9684
# Epoch 31/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.9455 - loss: 0.1725
# Epoch 31: val_accuracy did not improve from 0.91434
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 331ms/step - accuracy: 0.9454 - loss: 0.1726 - val_accuracy: 0.8658 - val_loss: 0.4511
# Epoch 32/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.9480 - loss: 0.1553
# Epoch 32: val_accuracy did not improve from 0.91434
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 328ms/step - accuracy: 0.9480 - loss: 0.1553 - val_accuracy: 0.5893 - val_loss: 1.5279
# Epoch 33/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.9416 - loss: 0.1727
# Epoch 33: val_accuracy did not improve from 0.91434
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 325ms/step - accuracy: 0.9416 - loss: 0.1728 - val_accuracy: 0.8287 - val_loss: 0.5148
# Epoch 34/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.9538 - loss: 0.1661
# Epoch 34: val_accuracy did not improve from 0.91434
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 325ms/step - accuracy: 0.9537 - loss: 0.1663 - val_accuracy: 0.7492 - val_loss: 0.9056
# Epoch 35/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 0.9505 - loss: 0.1548
# Epoch 35: val_accuracy did not improve from 0.91434
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 324ms/step - accuracy: 0.9505 - loss: 0.1547 - val_accuracy: 0.7812 - val_loss: 0.6439
# Epoch 36/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.9621 - loss: 0.1204
# Epoch 36: val_accuracy did not improve from 0.91434
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 326ms/step - accuracy: 0.9620 - loss: 0.1206 - val_accuracy: 0.8700 - val_loss: 0.4144
# Epoch 37/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9571 - loss: 0.1343
# Epoch 37: val_accuracy did not improve from 0.91434
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 329ms/step - accuracy: 0.9570 - loss: 0.1343 - val_accuracy: 0.9133 - val_loss: 0.2758
# Epoch 38/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.9481 - loss: 0.1524
# Epoch 38: val_accuracy did not improve from 0.91434
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 327ms/step - accuracy: 0.9481 - loss: 0.1523 - val_accuracy: 0.8019 - val_loss: 0.6778
# Epoch 39/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.9579 - loss: 0.1367
# Epoch 39: val_accuracy did not improve from 0.91434
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 327ms/step - accuracy: 0.9578 - loss: 0.1367 - val_accuracy: 0.8163 - val_loss: 0.7828
# Epoch 40/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.9572 - loss: 0.1293
# Epoch 40: val_accuracy did not improve from 0.91434
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 326ms/step - accuracy: 0.9571 - loss: 0.1294 - val_accuracy: 0.8999 - val_loss: 0.3272
# Epoch 41/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.9625 - loss: 0.1236
# Epoch 41: val_accuracy did not improve from 0.91434
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 41s 333ms/step - accuracy: 0.9624 - loss: 0.1237 - val_accuracy: 0.8235 - val_loss: 0.6101
# Epoch 42/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9597 - loss: 0.1448
# Epoch 42: val_accuracy did not improve from 0.91434
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 328ms/step - accuracy: 0.9598 - loss: 0.1447 - val_accuracy: 0.6584 - val_loss: 1.9516
# Epoch 43/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.9664 - loss: 0.1153
# Epoch 43: val_accuracy did not improve from 0.91434
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 329ms/step - accuracy: 0.9664 - loss: 0.1155 - val_accuracy: 0.7575 - val_loss: 0.8228
# Epoch 44/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9499 - loss: 0.1353
# Epoch 44: val_accuracy did not improve from 0.91434
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 328ms/step - accuracy: 0.9500 - loss: 0.1352 - val_accuracy: 0.8813 - val_loss: 0.5933
# Epoch 45/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.9628 - loss: 0.1024
# Epoch 45: val_accuracy did not improve from 0.91434
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 326ms/step - accuracy: 0.9629 - loss: 0.1024 - val_accuracy: 0.6708 - val_loss: 1.3581
# Epoch 46/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9681 - loss: 0.0963
# Epoch 46: val_accuracy did not improve from 0.91434
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 328ms/step - accuracy: 0.9681 - loss: 0.0964 - val_accuracy: 0.8927 - val_loss: 0.3346
# Epoch 47/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.9607 - loss: 0.1190
# Epoch 47: val_accuracy did not improve from 0.91434
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 40s 323ms/step - accuracy: 0.9607 - loss: 0.1189 - val_accuracy: 0.7564 - val_loss: 0.7952
# Epoch 47: early stopping
# Restoring model weights from the end of the best epoch: 37.
#
# Fold 5 - Validation Accuracy: 0.9133

# %%
# K-Fold Results Summary
print("K-FOLD CROSS VALIDATION RESULTS")

fold_accuracies = [score['val_accuracy'] for score in fold_scores]
print(f"Fold Accuracies: {[f'{acc:.4f}' for acc in fold_accuracies]}")
print(f"\nMean Accuracy: {np.mean(fold_accuracies):.4f}")
print(f"Best Fold: {np.argmax(fold_accuracies) + 1} with accuracy {np.max(fold_accuracies):.4f}")
# Out:
# K-FOLD CROSS VALIDATION RESULTS
# Fold Accuracies: ['0.8258', '0.8175', '0.6948', '0.9391', '0.9133']
#
# Mean Accuracy: 0.8381
# Best Fold: 4 with accuracy 0.9391

# %%
# Final Evaluation pada Test Set (Unseen Data)
print(f"\n{'='*60}")
print("FINAL EVALUATION ON UNSEEN TEST SET")
print(f"Using: {'AVG (Average of all {K_FOLDS} folds)' if USE_AVG else f'BEST FOLD (Fold {np.argmax(fold_accuracies) + 1})'}")
print(f"{'='*60}\n")

y_test_cat = tf.keras.utils.to_categorical(y_test, NUM_CLASSES)

if USE_AVG:
    # AVG: Rata-rata prediksi dari semua fold
    print("Generating predictions from all folds (Averaging)...")
    all_predictions = []

    for i, model in enumerate(fold_models):
        pred = model.predict(X_test, verbose=0)
        all_predictions.append(pred)
        print(f"  Fold {i+1} predictions generated")

    # Average predictions (Model Averaging)
    y_pred_probs = np.mean(all_predictions, axis=0)
    y_pred = np.argmax(y_pred_probs, axis=1)

    # Calculate average loss
    test_loss = tf.keras.losses.categorical_crossentropy(y_test_cat, y_pred_probs).numpy().mean()
    test_acc = accuracy_score(y_test, y_pred)

    print(f"\nAverage Model Test Loss: {test_loss:.4f}")
    print(f"Average Model Test Accuracy: {test_acc:.4f}\n")

else:
    # BEST FOLD: Gunakan model terbaik saja
    best_fold_idx = np.argmax(fold_accuracies)
    best_model = fold_models[best_fold_idx]
    print(f"Using model from Fold {best_fold_idx + 1}")

    test_loss, test_acc = best_model.evaluate(X_test, y_test_cat, verbose=0)
    y_pred_probs = best_model.predict(X_test, verbose=0)
    y_pred = np.argmax(y_pred_probs, axis=1)

    print(f"\nBest Fold Test Loss: {test_loss:.4f}")
    print(f"Best Fold Test Accuracy: {test_acc:.4f}\n")

# Classification Report
print("Classification Report:")
print(classification_report(y_test, y_pred, target_names=class_names))

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)

plt.title(f'Confusion Matrix - Test Set (Baseline)\n{"Average Mode" if USE_AVG else "Best Fold"}')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.tight_layout()
plt.savefig('/content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_matrix.png', dpi=300)
plt.show()
# Out:
# ============================================================
# FINAL EVALUATION ON UNSEEN TEST SET
# Using: AVG (Average of all {K_FOLDS} folds)
# ============================================================
#
# Generating predictions from all folds (Averaging)...
#   Fold 1 predictions generated
#   Fold 2 predictions generated
#   Fold 3 predictions generated
#   Fold 4 predictions generated
#   Fold 5 predictions generated
#
# Average Model Test Loss: 0.2715
# Average Model Test Accuracy: 0.9340
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        blast       0.96      0.98      0.97       348
#   brown_spot       0.99      0.84      0.91       193
#        hispa       0.96      0.89      0.92       319
#       normal       0.87      0.98      0.92       353
#
#     accuracy                           0.93      1213
#    macro avg       0.95      0.92      0.93      1213
# weighted avg       0.94      0.93      0.93      1213

# %%
# plot hasil 5 fold
plt.figure(figsize=(14, 5))

# --- PLOT AKURASI (KIRI) ---
plt.subplot(1, 2, 1)
for i, h in enumerate(fold_histories):
    # Plot tiap fold dengan warna abu-abu
    plt.plot(h['val_accuracy'], label=f'Fold {i+1}', alpha=0.5)

plt.title('Akurasi Validasi (5 Fold)')
plt.xlabel('Epoch')
plt.ylabel('Akurasi')
plt.legend()
plt.grid(True)

# --- PLOT LOSS (KANAN) ---
plt.subplot(1, 2, 2)
for i, h in enumerate(fold_histories):
    # Plot tiap fold dengan warna abu-abu
    plt.plot(h['val_loss'], label=f'Fold {i+1}', alpha=0.5)

plt.title('Loss Validasi (5 Fold)')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.savefig('/content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/training_history_baseline.png', dpi=300)
plt.show()

# %%
plt.figure(figsize=(15, 12))

for i, class_name in enumerate(class_names):
    # ambil semua index yang termasuk kelas ini
    indices = np.where(y_test == i)[0]
    # pilih 5 secara acak
    selected_indices = np.random.choice(indices, 5, replace=False)

    for j, idx in enumerate(selected_indices):
        plt.subplot(NUM_CLASSES, 5, i * 5 + j + 1)
        plt.imshow(X_test[idx])

        # prediksi vs Asli
        p_idx = y_pred[idx]
        is_correct = (i == p_idx)

        title = f"Actual: {class_name}\nPred: {class_names[p_idx]}"
        plt.title(title, color='green' if is_correct else 'red', fontsize=9)
        plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Save Models & Results

# Save semua model fold (format .keras)
for i, model in enumerate(fold_models):
    model_path = f'/content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold{i+1}_final.keras'
    model.save(model_path)
    print(f"Fold {i+1} model saved: {model_path}")

# Save hasil k-fold
results = {
    'fold_scores': fold_scores,
    'fold_histories': fold_histories,
    'test_accuracy': test_acc,
    'test_loss': test_loss,
    'class_names': class_names,
    'confusion_matrix': cm,
    'use_avg': USE_AVG,
    'num_folds': K_FOLDS,
    'mean_val_accuracy': np.mean(fold_accuracies),
    'std_val_accuracy': np.std(fold_accuracies),
    'predictions': y_pred,
    'prediction_probs': y_pred_probs,
    'model_type': 'baseline'
}

with open('/content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/kfold_results_skenario 2A.pkl', 'wb') as f:
    pickle.dump(results, f)

print(f"\nResults saved to: /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/kfold_results_skenario 2A.pkl")


print(f"\nFinal Test Accuracy: {test_acc:.4f}")
print(f"Model saved: /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/")
print(f"Format: .keras")
if USE_AVG:
    print(f"Mode: AVG ({K_FOLDS} models)")
else:
    print(f"Mode: BEST FOLD (Fold {np.argmax(fold_accuracies) + 1})")
# Out:
# Fold 1 model saved: /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold1_final.keras
# Fold 2 model saved: /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold2_final.keras
# Fold 3 model saved: /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold3_final.keras
# Fold 4 model saved: /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold4_final.keras
# Fold 5 model saved: /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold5_final.keras
#
# Results saved to: /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/kfold_results_skenario 2A.pkl
#
# Final Test Accuracy: 0.9340
# Model saved: /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/
# Format: .keras
# Mode: AVG (5 models)

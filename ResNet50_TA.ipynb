# %%
# SYSTEM & FILE (Untuk akses Drive, folder, dan simpan hasil)
from google.colab import drive
import os
from glob import glob
import pickle
import gc # Penting buat bersihin RAM tiap ganti Fold

# DATA & VISUALISASI (Olah gambar dan bikin grafik)
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2

# TENSORFLOW/KERAS
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# MACHINE LEARNING UTILS (Bagi data dan evaluasi)
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
# Mount Google Drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Configuration & Hyperparameters

# !cp -r "/content/drive/MyDrive/220411100023_Ali Ridho/Triplet/Dataset/Paddy doc" "/content/"
DATASET_PATH = "/content/Paddy doc"  # Path lokal di colab

# Hyperparameters
IMG_SIZE = 224
BATCH_SIZE = 32
EPOCHS = 100
PATIENCE = 10
LEARNING_RATE = 0.001
NUM_CLASSES = 4
K_FOLDS = 5
TEST_SPLIT = 0.2  # 80% train, 20% test (unseen)

# PILIH MODE EVALUASI
USE_AVG = True

# Random seed untuk reproducibility
SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
# Load dan Prepare Dataset

def load_dataset(dataset_path):
    images = []
    labels = []
    class_names = sorted(os.listdir(dataset_path))

    print(f"Class names: {class_names}")

    for idx, class_name in enumerate(class_names):
        class_path = os.path.join(dataset_path, class_name)
        if not os.path.isdir(class_path):
            continue

        image_files = glob(os.path.join(class_path, '*.*'))
        print(f"Class {class_name}: {len(image_files)} images")

        for img_path in image_files:
            try:
                img = cv2.imread(img_path)
                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
                images.append(img)
                labels.append(idx)
            except Exception as e:
                print(f"Error loading {img_path}: {e}")

    images = np.array(images, dtype='float32')
    labels = np.array(labels)

    print(f"\nTotal images: {len(images)}")
    print(f"Image shape: {images.shape}")
    print(f"Image value range: [{images.min()}, {images.max()}]")
    print(f"Labels shape: {labels.shape}")

    return images, labels, class_names

# Load dataset dari local storage
print(f"Loading dataset from: {DATASET_PATH}")
X, y, class_names = load_dataset(DATASET_PATH)

# Rescale images ke [0, 1]
print("\nRescaling images from [0, 255] to [0, 1]...")
X = X / 255.0
print(f"After rescaling: [{X.min()}, {X.max()}]")

# Split train-test (test adalah unseen data)
X_train_full, X_test, y_train_full, y_test = train_test_split(
    X, y, test_size=TEST_SPLIT, stratify=y, random_state=SEED
)

print(f"\nTrain set: {len(X_train_full)} images")
print(f"Test set (unseen): {len(X_test)} images")
# Out:
# Loading dataset from: /content/Paddy doc
# Class names: ['blast', 'brown_spot', 'hispa', 'normal']
# Class blast: 1738 images
# Class brown_spot: 965 images
# Class hispa: 1594 images
# Class normal: 1764 images
#
# Total images: 6061
# Image shape: (6061, 224, 224, 3)
# Image value range: [0.0, 255.0]
# Labels shape: (6061,)
#
# Rescaling images from [0, 255] to [0, 1]...
# After rescaling: [0.0, 1.0]
#
# Train set: 4848 images
# Test set (unseen): 1213 images

# %%
# ============================================================
# RANDOM OVERSAMPLING (Menyeimbangkan kelas di training set)
# ============================================================
from collections import Counter

print("\nDistribusi kelas SEBELUM oversampling:")
print(Counter(y_train_full))

# Cari jumlah sampel kelas terbanyak
max_count = max(Counter(y_train_full).values())

X_balanced = list(X_train_full)
y_balanced = list(y_train_full)

np.random.seed(SEED)

for class_idx in range(NUM_CLASSES):
    # Ambil semua index yang termasuk kelas ini
    class_indices = np.where(y_train_full == class_idx)[0]
    current_count = len(class_indices)

    # Hitung berapa yang perlu ditambah
    n_to_add = max_count - current_count

    if n_to_add > 0:
        # Pilih secara acak index yang akan diduplikasi
        extra_indices = np.random.choice(class_indices, n_to_add, replace=True)
        X_balanced.extend(X_train_full[extra_indices])
        y_balanced.extend(y_train_full[extra_indices])

# Convert balik ke numpy array
X_train_full = np.array(X_balanced, dtype='float32')
y_train_full = np.array(y_balanced)

print("\nDistribusi kelas SETELAH oversampling:")
print(Counter(y_train_full))
print(f"Total training data setelah oversampling: {len(X_train_full)}")
# Out:
# Distribusi kelas SEBELUM oversampling:
# Counter({np.int64(3): 1411, np.int64(0): 1390, np.int64(2): 1275, np.int64(1): 772})
#
# Distribusi kelas SETELAH oversampling:
# Counter({np.int64(0): 1411, np.int64(2): 1411, np.int64(1): 1411, np.int64(3): 1411})
# Total training data setelah oversampling: 5644

# %%
# TRIPLET ATTENTION MODULES
class ZPool(layers.Layer):
    """Z-Pooling: Concatenate max and mean pooling along channel dimension"""
    def call(self, x):
        max_pool = tf.reduce_max(x, axis=-1, keepdims=True) #ambil nilai max
        mean_pool = tf.reduce_mean(x, axis=-1, keepdims=True) #ambil nilai rata-rata
        return tf.concat([max_pool, mean_pool], axis=-1)

#conv 7x7
class AttentionGate(layers.Layer):
    def __init__(self, kernel_size=7, **kwargs):
        super(AttentionGate, self).__init__(**kwargs)
        self.compress = ZPool()
        self.conv = layers.Conv2D(1, kernel_size, padding='same', use_bias=False)
        self.bn = layers.BatchNormalization()
        self.activation = layers.Activation('sigmoid')

    def call(self, x):
        x_compress = self.compress(x) #ambil nilai avg & max
        x_out = self.conv(x_compress) #conv 7x7 dan digabung
        x_out = self.bn(x_out)
        scale = self.activation(x_out) #sigmoid
        return x * scale # * attention weight


class TripletAttention(layers.Layer):
    """
    Triplet Attention Module
    Menangkap dependencies cross-dimension: H-W, C-W, H-C
    Dengan mentranspose, kita "menipu" AttentionGate untuk berpikir bahwa channel atau width adalah
    dimensi spasial, sehingga perhatian diterapkan ke dimensi yang berbeda.
    """
    def __init__(self, **kwargs):
        super(TripletAttention, self).__init__(**kwargs)
        self.cw_gate = AttentionGate()
        self.hc_gate = AttentionGate()
        self.hw_gate = AttentionGate()

    def call(self, x):
        # cabang 1 H-W (tanpa transpose)
        x_hw = self.hw_gate(x)

        # Cabang 2C-W
        x_perm1 = tf.transpose(x, perm=[0, 3, 2, 1])  # Transpose: (B, H, W, C) -> (B, C, W, H)
        x_cw = self.cw_gate(x_perm1)
        x_cw = tf.transpose(x_cw, perm=[0, 3, 2, 1]) # Transpose kembali: (B, C, W, H) -> (B, H, W, C)

        # Cabang 3 H-C
        x_perm2 = tf.transpose(x, perm=[0, 1, 3, 2]) # Transpose: (B, H, W, C) -> (B, H, C, W)
        x_hc = self.hc_gate(x_perm2)
        x_hc = tf.transpose(x_hc, perm=[0, 1, 3, 2]) # Transpose kembali: (B, H, C, W) -> (B, H, W, C)

        return (x_hw + x_cw + x_hc) / 3 # Rata-rata dari ketiga cabang

# %%
# BOTTLENECK BLOCK

def bottleneck_block(x, filters, stride=1, downsample=False, name=None):
    shortcut = x
    in_channels = x.shape[-1]

    # Conv 1x1
    x = layers.Conv2D(filters, (1, 1), strides=stride, padding='same',
                     use_bias=False, name=f"{name}_1_conv")(x)
    x = layers.BatchNormalization(name=f"{name}_1_bn")(x)
    x = layers.Activation('relu', name=f"{name}_1_relu")(x)

    # Conv 3x3
    x = layers.Conv2D(filters, (3, 3), strides=1, padding='same',
                     use_bias=False, name=f"{name}_2_conv")(x)
    x = layers.BatchNormalization(name=f"{name}_2_bn")(x)
    x = layers.Activation('relu', name=f"{name}_2_relu")(x)

    # Conv 1x1N
    x = layers.Conv2D(filters * 4, (1, 1), strides=1, padding='same',
                     use_bias=False, name=f"{name}_3_conv")(x)
    x = layers.BatchNormalization(name=f"{name}_3_bn")(x)

    # Shortcut connection
    if downsample or in_channels != filters * 4:
        shortcut = layers.Conv2D(filters * 4, (1, 1), strides=stride,
                                padding='same', use_bias=False,
                                name=f"{name}_0_conv")(shortcut)
        shortcut = layers.BatchNormalization(name=f"{name}_0_bn")(shortcut)

    # Add shortcut + relu
    x = layers.Add(name=f"{name}_add")([x, shortcut])
    x = layers.Activation('relu', name=f"{name}_out")(x)

    return x

# %%
# ResNet-50 + Triplet Attention Architecture
def build_resnet50_triplet_attention(num_classes=4, input_shape=(224, 224, 3),use_attention=True):
    inputs = layers.Input(shape=input_shape)

    # Initial layers
    x = layers.Conv2D(64, (7, 7), strides=2, padding='same', use_bias=False, name="stem_conv")(inputs)
    x = layers.BatchNormalization(name="stem_bn")(x)
    x = layers.Activation('relu', name="stem_relu")(x)
    x = layers.MaxPooling2D((3, 3), strides=2, padding='same', name="stem_pool")(x)

    # Stage
    block_counts = [3, 4, 6, 3]
    filter_sizes = [64, 128, 256, 512]

    for stage, (filters, blocks) in enumerate(zip(filter_sizes, block_counts)):
        print(f"Building Stage {stage + 2} with {blocks} blocks, filters={filters}")

        for block in range(blocks):
            downsample = (block == 0)
            stride = 2 if (block == 0 and stage != 0) else 1
            block_name = f"stage{stage + 2}_block{block + 1}"

            x = bottleneck_block(x, filters, stride=stride,
                               downsample=downsample, name=block_name)

        # TRIPLET ATTENTION DI AKHIR SETIAP STAGE
        if use_attention:
            x = TripletAttention(name=f"triplet_attention_stage{stage + 2}")(x)
            print(f"  ✅ Triplet Attention added at Stage {stage + 2}")

    # CLASSIFICATION HEAD
    x = layers.GlobalAveragePooling2D(name="avg_pool")(x)
    outputs = layers.Dense(num_classes, activation='softmax', name="predictions")(x)
    model_name = "ResNet50_TA" if use_attention else "ResNet50_Baseline"
    model = models.Model(inputs, outputs, name=model_name)

    return model

# SUMMARY Model
model = build_resnet50_triplet_attention(
    num_classes=NUM_CLASSES,
    input_shape=(IMG_SIZE, IMG_SIZE, 3),
    use_attention=True
)
model.summary()

# Cleanup
import gc
del model
tf.keras.backend.clear_session()
gc.collect()
# Out:
# Building Stage 2 with 3 blocks, filters=64
#   ✅ Triplet Attention added at Stage 2
# Building Stage 3 with 4 blocks, filters=128
#   ✅ Triplet Attention added at Stage 3
# Building Stage 4 with 6 blocks, filters=256
#   ✅ Triplet Attention added at Stage 4
# Building Stage 5 with 3 blocks, filters=512
#   ✅ Triplet Attention added at Stage 5
# Model: "ResNet50_TA"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_conv (Conv2D)  │ (None, 112, 112,  │      9,408 │ input_layer[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_bn             │ (None, 112, 112,  │        256 │ stem_conv[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_relu           │ (None, 112, 112,  │          0 │ stem_bn[0][0]     │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_pool           │ (None, 56, 56,    │          0 │ stem_relu[0][0]   │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_1_co… │ (None, 56, 56,    │      4,096 │ stem_pool[0][0]   │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_1_bn  │ (None, 56, 56,    │        256 │ stage2_block1_1_… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_1_re… │ (None, 56, 56,    │          0 │ stage2_block1_1_… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_2_co… │ (None, 56, 56,    │     36,864 │ stage2_block1_1_… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_2_bn  │ (None, 56, 56,    │        256 │ stage2_block1_2_… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_2_re… │ (None, 56, 56,    │          0 │ stage2_block1_2_… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_3_co… │ (None, 56, 56,    │     16,384 │ stage2_block1_2_… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_0_co… │ (None, 56, 56,    │     16,384 │ stem_pool[0][0]   │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_3_bn  │ (None, 56, 56,    │      1,024 │ stage2_block1_3_… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_0_bn  │ (None, 56, 56,    │      1,024 │ stage2_block1_0_… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_add   │ (None, 56, 56,    │          0 │ stage2_block1_3_… │
# │ (Add)               │ 256)              │            │ stage2_block1_0_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block1_out   │ (None, 56, 56,    │          0 │ stage2_block1_ad… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block2_1_co… │ (None, 56, 56,    │     16,384 │ stage2_block1_ou… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block2_1_bn  │ (None, 56, 56,    │        256 │ stage2_block2_1_… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block2_1_re… │ (None, 56, 56,    │          0 │ stage2_block2_1_… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block2_2_co… │ (None, 56, 56,    │     36,864 │ stage2_block2_1_… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block2_2_bn  │ (None, 56, 56,    │        256 │ stage2_block2_2_… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block2_2_re… │ (None, 56, 56,    │          0 │ stage2_block2_2_… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block2_3_co… │ (None, 56, 56,    │     16,384 │ stage2_block2_2_… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block2_3_bn  │ (None, 56, 56,    │      1,024 │ stage2_block2_3_… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block2_add   │ (None, 56, 56,    │          0 │ stage2_block2_3_… │
# │ (Add)               │ 256)              │            │ stage2_block1_ou… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block2_out   │ (None, 56, 56,    │          0 │ stage2_block2_ad… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block3_1_co… │ (None, 56, 56,    │     16,384 │ stage2_block2_ou… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block3_1_bn  │ (None, 56, 56,    │        256 │ stage2_block3_1_… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block3_1_re… │ (None, 56, 56,    │          0 │ stage2_block3_1_… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block3_2_co… │ (None, 56, 56,    │     36,864 │ stage2_block3_1_… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block3_2_bn  │ (None, 56, 56,    │        256 │ stage2_block3_2_… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block3_2_re… │ (None, 56, 56,    │          0 │ stage2_block3_2_… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block3_3_co… │ (None, 56, 56,    │     16,384 │ stage2_block3_2_… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block3_3_bn  │ (None, 56, 56,    │      1,024 │ stage2_block3_3_… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block3_add   │ (None, 56, 56,    │          0 │ stage2_block3_3_… │
# │ (Add)               │ 256)              │            │ stage2_block2_ou… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage2_block3_out   │ (None, 56, 56,    │          0 │ stage2_block3_ad… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ triplet_attention_… │ (None, 56, 56,    │        306 │ stage2_block3_ou… │
# │ (TripletAttention)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_1_co… │ (None, 28, 28,    │     32,768 │ triplet_attentio… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_1_bn  │ (None, 28, 28,    │        512 │ stage3_block1_1_… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_1_re… │ (None, 28, 28,    │          0 │ stage3_block1_1_… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_2_co… │ (None, 28, 28,    │    147,456 │ stage3_block1_1_… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_2_bn  │ (None, 28, 28,    │        512 │ stage3_block1_2_… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_2_re… │ (None, 28, 28,    │          0 │ stage3_block1_2_… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_3_co… │ (None, 28, 28,    │     65,536 │ stage3_block1_2_… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_0_co… │ (None, 28, 28,    │    131,072 │ triplet_attentio… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_3_bn  │ (None, 28, 28,    │      2,048 │ stage3_block1_3_… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_0_bn  │ (None, 28, 28,    │      2,048 │ stage3_block1_0_… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_add   │ (None, 28, 28,    │          0 │ stage3_block1_3_… │
# │ (Add)               │ 512)              │            │ stage3_block1_0_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block1_out   │ (None, 28, 28,    │          0 │ stage3_block1_ad… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block2_1_co… │ (None, 28, 28,    │     65,536 │ stage3_block1_ou… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block2_1_bn  │ (None, 28, 28,    │        512 │ stage3_block2_1_… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block2_1_re… │ (None, 28, 28,    │          0 │ stage3_block2_1_… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block2_2_co… │ (None, 28, 28,    │    147,456 │ stage3_block2_1_… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block2_2_bn  │ (None, 28, 28,    │        512 │ stage3_block2_2_… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block2_2_re… │ (None, 28, 28,    │          0 │ stage3_block2_2_… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block2_3_co… │ (None, 28, 28,    │     65,536 │ stage3_block2_2_… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block2_3_bn  │ (None, 28, 28,    │      2,048 │ stage3_block2_3_… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block2_add   │ (None, 28, 28,    │          0 │ stage3_block2_3_… │
# │ (Add)               │ 512)              │            │ stage3_block1_ou… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block2_out   │ (None, 28, 28,    │          0 │ stage3_block2_ad… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block3_1_co… │ (None, 28, 28,    │     65,536 │ stage3_block2_ou… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block3_1_bn  │ (None, 28, 28,    │        512 │ stage3_block3_1_… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block3_1_re… │ (None, 28, 28,    │          0 │ stage3_block3_1_… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block3_2_co… │ (None, 28, 28,    │    147,456 │ stage3_block3_1_… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block3_2_bn  │ (None, 28, 28,    │        512 │ stage3_block3_2_… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block3_2_re… │ (None, 28, 28,    │          0 │ stage3_block3_2_… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block3_3_co… │ (None, 28, 28,    │     65,536 │ stage3_block3_2_… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block3_3_bn  │ (None, 28, 28,    │      2,048 │ stage3_block3_3_… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block3_add   │ (None, 28, 28,    │          0 │ stage3_block3_3_… │
# │ (Add)               │ 512)              │            │ stage3_block2_ou… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block3_out   │ (None, 28, 28,    │          0 │ stage3_block3_ad… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block4_1_co… │ (None, 28, 28,    │     65,536 │ stage3_block3_ou… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block4_1_bn  │ (None, 28, 28,    │        512 │ stage3_block4_1_… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block4_1_re… │ (None, 28, 28,    │          0 │ stage3_block4_1_… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block4_2_co… │ (None, 28, 28,    │    147,456 │ stage3_block4_1_… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block4_2_bn  │ (None, 28, 28,    │        512 │ stage3_block4_2_… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block4_2_re… │ (None, 28, 28,    │          0 │ stage3_block4_2_… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block4_3_co… │ (None, 28, 28,    │     65,536 │ stage3_block4_2_… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block4_3_bn  │ (None, 28, 28,    │      2,048 │ stage3_block4_3_… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block4_add   │ (None, 28, 28,    │          0 │ stage3_block4_3_… │
# │ (Add)               │ 512)              │            │ stage3_block3_ou… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage3_block4_out   │ (None, 28, 28,    │          0 │ stage3_block4_ad… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ triplet_attention_… │ (None, 28, 28,    │        306 │ stage3_block4_ou… │
# │ (TripletAttention)  │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_1_co… │ (None, 14, 14,    │    131,072 │ triplet_attentio… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_1_bn  │ (None, 14, 14,    │      1,024 │ stage4_block1_1_… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_1_re… │ (None, 14, 14,    │          0 │ stage4_block1_1_… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_2_co… │ (None, 14, 14,    │    589,824 │ stage4_block1_1_… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_2_bn  │ (None, 14, 14,    │      1,024 │ stage4_block1_2_… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_2_re… │ (None, 14, 14,    │          0 │ stage4_block1_2_… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_3_co… │ (None, 14, 14,    │    262,144 │ stage4_block1_2_… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_0_co… │ (None, 14, 14,    │    524,288 │ triplet_attentio… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_3_bn  │ (None, 14, 14,    │      4,096 │ stage4_block1_3_… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_0_bn  │ (None, 14, 14,    │      4,096 │ stage4_block1_0_… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_add   │ (None, 14, 14,    │          0 │ stage4_block1_3_… │
# │ (Add)               │ 1024)             │            │ stage4_block1_0_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block1_out   │ (None, 14, 14,    │          0 │ stage4_block1_ad… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block2_1_co… │ (None, 14, 14,    │    262,144 │ stage4_block1_ou… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block2_1_bn  │ (None, 14, 14,    │      1,024 │ stage4_block2_1_… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block2_1_re… │ (None, 14, 14,    │          0 │ stage4_block2_1_… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block2_2_co… │ (None, 14, 14,    │    589,824 │ stage4_block2_1_… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block2_2_bn  │ (None, 14, 14,    │      1,024 │ stage4_block2_2_… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block2_2_re… │ (None, 14, 14,    │          0 │ stage4_block2_2_… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block2_3_co… │ (None, 14, 14,    │    262,144 │ stage4_block2_2_… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block2_3_bn  │ (None, 14, 14,    │      4,096 │ stage4_block2_3_… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block2_add   │ (None, 14, 14,    │          0 │ stage4_block2_3_… │
# │ (Add)               │ 1024)             │            │ stage4_block1_ou… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block2_out   │ (None, 14, 14,    │          0 │ stage4_block2_ad… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block3_1_co… │ (None, 14, 14,    │    262,144 │ stage4_block2_ou… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block3_1_bn  │ (None, 14, 14,    │      1,024 │ stage4_block3_1_… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block3_1_re… │ (None, 14, 14,    │          0 │ stage4_block3_1_… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block3_2_co… │ (None, 14, 14,    │    589,824 │ stage4_block3_1_… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block3_2_bn  │ (None, 14, 14,    │      1,024 │ stage4_block3_2_… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block3_2_re… │ (None, 14, 14,    │          0 │ stage4_block3_2_… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block3_3_co… │ (None, 14, 14,    │    262,144 │ stage4_block3_2_… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block3_3_bn  │ (None, 14, 14,    │      4,096 │ stage4_block3_3_… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block3_add   │ (None, 14, 14,    │          0 │ stage4_block3_3_… │
# │ (Add)               │ 1024)             │            │ stage4_block2_ou… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block3_out   │ (None, 14, 14,    │          0 │ stage4_block3_ad… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block4_1_co… │ (None, 14, 14,    │    262,144 │ stage4_block3_ou… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block4_1_bn  │ (None, 14, 14,    │      1,024 │ stage4_block4_1_… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block4_1_re… │ (None, 14, 14,    │          0 │ stage4_block4_1_… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block4_2_co… │ (None, 14, 14,    │    589,824 │ stage4_block4_1_… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block4_2_bn  │ (None, 14, 14,    │      1,024 │ stage4_block4_2_… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block4_2_re… │ (None, 14, 14,    │          0 │ stage4_block4_2_… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block4_3_co… │ (None, 14, 14,    │    262,144 │ stage4_block4_2_… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block4_3_bn  │ (None, 14, 14,    │      4,096 │ stage4_block4_3_… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block4_add   │ (None, 14, 14,    │          0 │ stage4_block4_3_… │
# │ (Add)               │ 1024)             │            │ stage4_block3_ou… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block4_out   │ (None, 14, 14,    │          0 │ stage4_block4_ad… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block5_1_co… │ (None, 14, 14,    │    262,144 │ stage4_block4_ou… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block5_1_bn  │ (None, 14, 14,    │      1,024 │ stage4_block5_1_… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block5_1_re… │ (None, 14, 14,    │          0 │ stage4_block5_1_… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block5_2_co… │ (None, 14, 14,    │    589,824 │ stage4_block5_1_… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block5_2_bn  │ (None, 14, 14,    │      1,024 │ stage4_block5_2_… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block5_2_re… │ (None, 14, 14,    │          0 │ stage4_block5_2_… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block5_3_co… │ (None, 14, 14,    │    262,144 │ stage4_block5_2_… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block5_3_bn  │ (None, 14, 14,    │      4,096 │ stage4_block5_3_… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block5_add   │ (None, 14, 14,    │          0 │ stage4_block5_3_… │
# │ (Add)               │ 1024)             │            │ stage4_block4_ou… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block5_out   │ (None, 14, 14,    │          0 │ stage4_block5_ad… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block6_1_co… │ (None, 14, 14,    │    262,144 │ stage4_block5_ou… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block6_1_bn  │ (None, 14, 14,    │      1,024 │ stage4_block6_1_… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block6_1_re… │ (None, 14, 14,    │          0 │ stage4_block6_1_… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block6_2_co… │ (None, 14, 14,    │    589,824 │ stage4_block6_1_… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block6_2_bn  │ (None, 14, 14,    │      1,024 │ stage4_block6_2_… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block6_2_re… │ (None, 14, 14,    │          0 │ stage4_block6_2_… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block6_3_co… │ (None, 14, 14,    │    262,144 │ stage4_block6_2_… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block6_3_bn  │ (None, 14, 14,    │      4,096 │ stage4_block6_3_… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block6_add   │ (None, 14, 14,    │          0 │ stage4_block6_3_… │
# │ (Add)               │ 1024)             │            │ stage4_block5_ou… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage4_block6_out   │ (None, 14, 14,    │          0 │ stage4_block6_ad… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ triplet_attention_… │ (None, 14, 14,    │        306 │ stage4_block6_ou… │
# │ (TripletAttention)  │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block1_1_co… │ (None, 7, 7, 512) │    524,288 │ triplet_attentio… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block1_1_bn  │ (None, 7, 7, 512) │      2,048 │ stage5_block1_1_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block1_1_re… │ (None, 7, 7, 512) │          0 │ stage5_block1_1_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block1_2_co… │ (None, 7, 7, 512) │  2,359,296 │ stage5_block1_1_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block1_2_bn  │ (None, 7, 7, 512) │      2,048 │ stage5_block1_2_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block1_2_re… │ (None, 7, 7, 512) │          0 │ stage5_block1_2_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block1_3_co… │ (None, 7, 7,      │  1,048,576 │ stage5_block1_2_… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block1_0_co… │ (None, 7, 7,      │  2,097,152 │ triplet_attentio… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block1_3_bn  │ (None, 7, 7,      │      8,192 │ stage5_block1_3_… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block1_0_bn  │ (None, 7, 7,      │      8,192 │ stage5_block1_0_… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block1_add   │ (None, 7, 7,      │          0 │ stage5_block1_3_… │
# │ (Add)               │ 2048)             │            │ stage5_block1_0_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block1_out   │ (None, 7, 7,      │          0 │ stage5_block1_ad… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block2_1_co… │ (None, 7, 7, 512) │  1,048,576 │ stage5_block1_ou… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block2_1_bn  │ (None, 7, 7, 512) │      2,048 │ stage5_block2_1_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block2_1_re… │ (None, 7, 7, 512) │          0 │ stage5_block2_1_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block2_2_co… │ (None, 7, 7, 512) │  2,359,296 │ stage5_block2_1_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block2_2_bn  │ (None, 7, 7, 512) │      2,048 │ stage5_block2_2_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block2_2_re… │ (None, 7, 7, 512) │          0 │ stage5_block2_2_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block2_3_co… │ (None, 7, 7,      │  1,048,576 │ stage5_block2_2_… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block2_3_bn  │ (None, 7, 7,      │      8,192 │ stage5_block2_3_… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block2_add   │ (None, 7, 7,      │          0 │ stage5_block2_3_… │
# │ (Add)               │ 2048)             │            │ stage5_block1_ou… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block2_out   │ (None, 7, 7,      │          0 │ stage5_block2_ad… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block3_1_co… │ (None, 7, 7, 512) │  1,048,576 │ stage5_block2_ou… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block3_1_bn  │ (None, 7, 7, 512) │      2,048 │ stage5_block3_1_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block3_1_re… │ (None, 7, 7, 512) │          0 │ stage5_block3_1_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block3_2_co… │ (None, 7, 7, 512) │  2,359,296 │ stage5_block3_1_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block3_2_bn  │ (None, 7, 7, 512) │      2,048 │ stage5_block3_2_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block3_2_re… │ (None, 7, 7, 512) │          0 │ stage5_block3_2_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block3_3_co… │ (None, 7, 7,      │  1,048,576 │ stage5_block3_2_… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block3_3_bn  │ (None, 7, 7,      │      8,192 │ stage5_block3_3_… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block3_add   │ (None, 7, 7,      │          0 │ stage5_block3_3_… │
# │ (Add)               │ 2048)             │            │ stage5_block2_ou… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stage5_block3_out   │ (None, 7, 7,      │          0 │ stage5_block3_ad… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ triplet_attention_… │ (None, 7, 7,      │        306 │ stage5_block3_ou… │
# │ (TripletAttention)  │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ avg_pool            │ (None, 2048)      │          0 │ triplet_attentio… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ predictions (Dense) │ (None, 4)         │      8,196 │ avg_pool[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 23,570,572 (89.91 MB)
#  Trainable params: 23,517,428 (89.71 MB)
#  Non-trainable params: 53,144 (207.59 KB)
# 0

# %%
# K-Fold Cross Validation Setup

kfold = StratifiedKFold(n_splits=K_FOLDS, shuffle=True, random_state=SEED)

# Storage untuk hasil setiap fold
fold_histories = []
fold_scores = []
fold_models = []

# %%
# Tahap training K-fold

for fold, (train_idx, val_idx) in enumerate(kfold.split(X_train_full, y_train_full)):
    print(f"\nFOLD {fold + 1}/{K_FOLDS}")

    # Pembagian data latih & validasi berdasarkan index K-Fold
    X_train_fold, X_val_fold = X_train_full[train_idx], X_train_full[val_idx]
    y_train_fold, y_val_fold = y_train_full[train_idx], y_train_full[val_idx]

    # mengubah label angka (0-3) menjadi vektor biner
    y_train_cat = tf.keras.utils.to_categorical(y_train_fold, NUM_CLASSES)
    y_val_cat = tf.keras.utils.to_categorical(y_val_fold, NUM_CLASSES)

    # Re-inisialisasi Model
    model = build_resnet50_triplet_attention(
        num_classes=NUM_CLASSES,
        input_shape=(IMG_SIZE, IMG_SIZE, 3),
        use_attention=True # Set True jika masuk skenario Triplet Attention
    )

    # Konfigurasi Optimizer
    model.compile(
        optimizer=optimizers.Adam(learning_rate=LEARNING_RATE),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    # callbacks
    checkpoint_path = f'/content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold{fold+1}_best.keras'
    os.makedirs(os.path.dirname(checkpoint_path), exist_ok=True)
    callbacks = [
        EarlyStopping(
            monitor='val_loss',
            patience=PATIENCE,
            restore_best_weights=True,
            verbose=1),

        ModelCheckpoint(
            checkpoint_path,
            monitor='val_accuracy',
            save_best_only=True,
            verbose=1)
    ]

    # augmentasi
    datagen = ImageDataGenerator(
        rotation_range=20, width_shift_range=0.2, height_shift_range=0.2,
        horizontal_flip=True, zoom_range=0.2, shear_range=0.2, fill_mode='nearest'
    )

    # proses Training
    history = model.fit(
        datagen.flow(X_train_fold, y_train_cat, batch_size=BATCH_SIZE),
        validation_data=(X_val_fold, y_val_cat),
        epochs=EPOCHS,
        callbacks=callbacks,
        verbose=1
    )

    # Evaluasi performa fold saat ini
    val_loss, val_acc = model.evaluate(X_val_fold, y_val_cat, verbose=0)
    print(f"\nFold {fold + 1} - Validation Accuracy: {val_acc:.4f}")

    # penyimpanan log history dan model
    fold_histories.append(history.history)
    fold_scores.append({'val_loss': val_loss, 'val_accuracy': val_acc})
    fold_models.append(model)

    # 10. Manajemen Memori (Menghapus cache RAM/GPU agar tidak crash di fold berikutnya)
    gc.collect()
    tf.keras.backend.clear_session()
# Out:
# FOLD 1/5
# Building Stage 2 with 3 blocks, filters=64
#   ✅ Triplet Attention added at Stage 2
# Building Stage 3 with 4 blocks, filters=128
#   ✅ Triplet Attention added at Stage 3
# Building Stage 4 with 6 blocks, filters=256
#   ✅ Triplet Attention added at Stage 4
# Building Stage 5 with 3 blocks, filters=512
#   ✅ Triplet Attention added at Stage 5
# Epoch 1/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 762ms/step - accuracy: 0.3735 - loss: 1.5689
# Epoch 1: val_accuracy improved from None to 0.24978, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold1_best.keras
#
# Epoch 1: finished saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold1_best.keras
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 256s 936ms/step - accuracy: 0.4436 - loss: 1.3025 - val_accuracy: 0.2498 - val_loss: 2.7168
# Epoch 2/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.5482 - loss: 1.0632
# Epoch 2: val_accuracy improved from 0.24978 to 0.25686, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold1_best.keras
#
# Epoch 2: finished saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold1_best.keras
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 49s 341ms/step - accuracy: 0.5750 - loss: 1.0205 - val_accuracy: 0.2569 - val_loss: 2.7065
# Epoch 3/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.6060 - loss: 0.9728
# Epoch 3: val_accuracy improved from 0.25686 to 0.26749, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold1_best.keras
#
# Epoch 3: finished saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold1_best.keras
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 49s 342ms/step - accuracy: 0.6394 - loss: 0.9043 - val_accuracy: 0.2675 - val_loss: 3.0418
# Epoch 4/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.7108 - loss: 0.7609
# Epoch 4: val_accuracy improved from 0.26749 to 0.45793, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold1_best.keras
#
# Epoch 4: finished saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold1_best.keras
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 49s 343ms/step - accuracy: 0.7178 - loss: 0.7313 - val_accuracy: 0.4579 - val_loss: 2.2752
# Epoch 5/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.7434 - loss: 0.6610
# Epoch 5: val_accuracy improved from 0.45793 to 0.50930, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold1_best.keras
#
# Epoch 5: finished saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold1_best.keras
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 50s 351ms/step - accuracy: 0.7493 - loss: 0.6480 - val_accuracy: 0.5093 - val_loss: 1.7163
# Epoch 6/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.7908 - loss: 0.5673
# Epoch 6: val_accuracy did not improve from 0.50930
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 329ms/step - accuracy: 0.7739 - loss: 0.5866 - val_accuracy: 0.3667 - val_loss: 1.9937
# Epoch 7/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.7927 - loss: 0.5463
# Epoch 7: val_accuracy did not improve from 0.50930
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 331ms/step - accuracy: 0.8044 - loss: 0.5325 - val_accuracy: 0.4464 - val_loss: 1.6317
# Epoch 8/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.7995 - loss: 0.5222
# Epoch 8: val_accuracy did not improve from 0.50930
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 328ms/step - accuracy: 0.7989 - loss: 0.5339 - val_accuracy: 0.3800 - val_loss: 2.6251
# Epoch 9/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - accuracy: 0.8280 - loss: 0.4698
# Epoch 9: val_accuracy improved from 0.50930 to 0.68025, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold1_best.keras
#
# Epoch 9: finished saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold1_best.keras
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 48s 336ms/step - accuracy: 0.8290 - loss: 0.4675 - val_accuracy: 0.6802 - val_loss: 1.0073
# Epoch 10/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.7810 - loss: 0.5729
# Epoch 10: val_accuracy did not improve from 0.68025
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 332ms/step - accuracy: 0.7945 - loss: 0.5488 - val_accuracy: 0.5562 - val_loss: 1.6138
# Epoch 11/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.8409 - loss: 0.4415
# Epoch 11: val_accuracy did not improve from 0.68025
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 327ms/step - accuracy: 0.8447 - loss: 0.4182 - val_accuracy: 0.6138 - val_loss: 1.2825
# Epoch 12/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.8309 - loss: 0.4493
# Epoch 12: val_accuracy did not improve from 0.68025
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 328ms/step - accuracy: 0.8532 - loss: 0.4002 - val_accuracy: 0.6678 - val_loss: 1.0490
# Epoch 13/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.8692 - loss: 0.3511
# Epoch 13: val_accuracy did not improve from 0.68025
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 328ms/step - accuracy: 0.8662 - loss: 0.3648 - val_accuracy: 0.6785 - val_loss: 1.2519
# Epoch 14/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.8768 - loss: 0.3373
# Epoch 14: val_accuracy did not improve from 0.68025
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 332ms/step - accuracy: 0.8726 - loss: 0.3491 - val_accuracy: 0.5926 - val_loss: 1.9421
# Epoch 15/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.8957 - loss: 0.2941
# Epoch 15: val_accuracy did not improve from 0.68025
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 46s 325ms/step - accuracy: 0.8875 - loss: 0.3136 - val_accuracy: 0.6599 - val_loss: 1.0768
# Epoch 16/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.8979 - loss: 0.2964
# Epoch 16: val_accuracy did not improve from 0.68025
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 46s 326ms/step - accuracy: 0.8999 - loss: 0.2847 - val_accuracy: 0.5199 - val_loss: 1.9242
# Epoch 17/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.9011 - loss: 0.2767
# Epoch 17: val_accuracy improved from 0.68025 to 0.76705, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold1_best.keras
#
# Epoch 17: finished saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold1_best.keras
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 49s 342ms/step - accuracy: 0.8924 - loss: 0.2951 - val_accuracy: 0.7671 - val_loss: 0.6869
# Epoch 18/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.9106 - loss: 0.2506
# Epoch 18: val_accuracy improved from 0.76705 to 0.80691, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold1_best.keras
#
# Epoch 18: finished saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold1_best.keras
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 49s 346ms/step - accuracy: 0.8941 - loss: 0.2915 - val_accuracy: 0.8069 - val_loss: 0.5503
# Epoch 19/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.8956 - loss: 0.3041
# Epoch 19: val_accuracy did not improve from 0.80691
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 329ms/step - accuracy: 0.8917 - loss: 0.3065 - val_accuracy: 0.7972 - val_loss: 0.5180
# Epoch 20/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.9060 - loss: 0.2654
# Epoch 20: val_accuracy did not improve from 0.80691
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 46s 326ms/step - accuracy: 0.8966 - loss: 0.2967 - val_accuracy: 0.3853 - val_loss: 2.6230
# Epoch 21/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.8740 - loss: 0.3293
# Epoch 21: val_accuracy did not improve from 0.80691
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 46s 326ms/step - accuracy: 0.8913 - loss: 0.2807 - val_accuracy: 0.5013 - val_loss: 1.9517
# Epoch 22/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.9293 - loss: 0.2090
# Epoch 22: val_accuracy did not improve from 0.80691
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 330ms/step - accuracy: 0.9296 - loss: 0.2127 - val_accuracy: 0.7892 - val_loss: 0.5898
# Epoch 23/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.9193 - loss: 0.2452
# Epoch 23: val_accuracy did not improve from 0.80691
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 330ms/step - accuracy: 0.9183 - loss: 0.2416 - val_accuracy: 0.6342 - val_loss: 1.3325
# Epoch 24/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.9309 - loss: 0.1974
# Epoch 24: val_accuracy improved from 0.80691 to 0.84677, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold1_best.keras
#
# Epoch 24: finished saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold1_best.keras
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 49s 346ms/step - accuracy: 0.9212 - loss: 0.2160 - val_accuracy: 0.8468 - val_loss: 0.4576
# Epoch 25/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.9273 - loss: 0.1927
# Epoch 25: val_accuracy did not improve from 0.84677
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 330ms/step - accuracy: 0.9123 - loss: 0.2443 - val_accuracy: 0.3720 - val_loss: 3.3282
# Epoch 26/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 0.8956 - loss: 0.3075
# Epoch 26: val_accuracy did not improve from 0.84677
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 46s 324ms/step - accuracy: 0.9012 - loss: 0.2866 - val_accuracy: 0.7883 - val_loss: 0.5784
# Epoch 27/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9319 - loss: 0.1965
# Epoch 27: val_accuracy did not improve from 0.84677
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 329ms/step - accuracy: 0.9318 - loss: 0.1947 - val_accuracy: 0.8388 - val_loss: 0.4365
# Epoch 28/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.9402 - loss: 0.1646
# Epoch 28: val_accuracy did not improve from 0.84677
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 333ms/step - accuracy: 0.9367 - loss: 0.1740 - val_accuracy: 0.8299 - val_loss: 0.6363
# Epoch 29/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9442 - loss: 0.1610
# Epoch 29: val_accuracy did not improve from 0.84677
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 48s 334ms/step - accuracy: 0.9453 - loss: 0.1558 - val_accuracy: 0.7759 - val_loss: 0.8855
# Epoch 30/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9513 - loss: 0.1416
# Epoch 30: val_accuracy did not improve from 0.84677
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 328ms/step - accuracy: 0.9493 - loss: 0.1475 - val_accuracy: 0.5890 - val_loss: 1.8729
# Epoch 31/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.9561 - loss: 0.1278
# Epoch 31: val_accuracy improved from 0.84677 to 0.91674, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold1_best.keras
#
# Epoch 31: finished saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold1_best.keras
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 49s 343ms/step - accuracy: 0.9508 - loss: 0.1456 - val_accuracy: 0.9167 - val_loss: 0.2686
# Epoch 32/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.9537 - loss: 0.1447
# Epoch 32: val_accuracy did not improve from 0.91674
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 48s 335ms/step - accuracy: 0.9557 - loss: 0.1367 - val_accuracy: 0.8733 - val_loss: 0.4235
# Epoch 33/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.9386 - loss: 0.1662
# Epoch 33: val_accuracy did not improve from 0.91674
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 327ms/step - accuracy: 0.9336 - loss: 0.1829 - val_accuracy: 0.5713 - val_loss: 3.5712
# Epoch 34/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.9274 - loss: 0.1967
# Epoch 34: val_accuracy did not improve from 0.91674
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 330ms/step - accuracy: 0.9276 - loss: 0.1974 - val_accuracy: 0.9123 - val_loss: 0.2216
# Epoch 35/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.9614 - loss: 0.1223
# Epoch 35: val_accuracy did not improve from 0.91674
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 330ms/step - accuracy: 0.9515 - loss: 0.1419 - val_accuracy: 0.5182 - val_loss: 1.9034
# Epoch 36/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.9236 - loss: 0.2201
# Epoch 36: val_accuracy did not improve from 0.91674
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 46s 326ms/step - accuracy: 0.9329 - loss: 0.1864 - val_accuracy: 0.5616 - val_loss: 1.7035
# Epoch 37/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.9521 - loss: 0.1354
# Epoch 37: val_accuracy did not improve from 0.91674
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 332ms/step - accuracy: 0.9413 - loss: 0.1647 - val_accuracy: 0.7910 - val_loss: 0.6648
# Epoch 38/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9557 - loss: 0.1270
# Epoch 38: val_accuracy did not improve from 0.91674
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 48s 334ms/step - accuracy: 0.9537 - loss: 0.1326 - val_accuracy: 0.9123 - val_loss: 0.3537
# Epoch 39/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9611 - loss: 0.0991
# Epoch 39: val_accuracy did not improve from 0.91674
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 328ms/step - accuracy: 0.9592 - loss: 0.1107 - val_accuracy: 0.7626 - val_loss: 1.0963
# Epoch 40/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.9586 - loss: 0.1164
# Epoch 40: val_accuracy did not improve from 0.91674
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 331ms/step - accuracy: 0.9573 - loss: 0.1226 - val_accuracy: 0.8955 - val_loss: 0.3447
# Epoch 41/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.9517 - loss: 0.1337
# Epoch 41: val_accuracy did not improve from 0.91674
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 46s 323ms/step - accuracy: 0.9497 - loss: 0.1433 - val_accuracy: 0.8415 - val_loss: 0.5386
# Epoch 42/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.9645 - loss: 0.1148
# Epoch 42: val_accuracy did not improve from 0.91674
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 46s 323ms/step - accuracy: 0.9637 - loss: 0.1088 - val_accuracy: 0.7298 - val_loss: 0.8688
# Epoch 43/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.9267 - loss: 0.2078
# Epoch 43: val_accuracy did not improve from 0.91674
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 328ms/step - accuracy: 0.9375 - loss: 0.1847 - val_accuracy: 0.9132 - val_loss: 0.3530
# Epoch 44/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.9753 - loss: 0.0833
# Epoch 44: val_accuracy improved from 0.91674 to 0.94420, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold1_best.keras
#
# Epoch 44: finished saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold1_best.keras
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 49s 345ms/step - accuracy: 0.9674 - loss: 0.0970 - val_accuracy: 0.9442 - val_loss: 0.1870
# Epoch 45/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.9604 - loss: 0.1329
# Epoch 45: val_accuracy did not improve from 0.94420
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 331ms/step - accuracy: 0.9437 - loss: 0.1644 - val_accuracy: 0.8539 - val_loss: 0.4781
# Epoch 46/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.9568 - loss: 0.1260
# Epoch 46: val_accuracy did not improve from 0.94420
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 331ms/step - accuracy: 0.9539 - loss: 0.1284 - val_accuracy: 0.8760 - val_loss: 0.3749
# Epoch 47/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9612 - loss: 0.1208
# Epoch 47: val_accuracy improved from 0.94420 to 0.95483, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold1_best.keras
#
# Epoch 47: finished saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold1_best.keras
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 49s 341ms/step - accuracy: 0.9663 - loss: 0.1046 - val_accuracy: 0.9548 - val_loss: 0.1460
# Epoch 48/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.9754 - loss: 0.0787
# Epoch 48: val_accuracy did not improve from 0.95483
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 46s 323ms/step - accuracy: 0.9641 - loss: 0.1130 - val_accuracy: 0.6554 - val_loss: 1.5109
# Epoch 49/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.9630 - loss: 0.1087
# Epoch 49: val_accuracy did not improve from 0.95483
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 331ms/step - accuracy: 0.9646 - loss: 0.1078 - val_accuracy: 0.9283 - val_loss: 0.2317
# Epoch 50/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.9378 - loss: 0.1800
# Epoch 50: val_accuracy did not improve from 0.95483
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 330ms/step - accuracy: 0.9322 - loss: 0.1956 - val_accuracy: 0.8158 - val_loss: 0.5155
# Epoch 51/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 0.9663 - loss: 0.1111
# Epoch 51: val_accuracy did not improve from 0.95483
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 46s 324ms/step - accuracy: 0.9648 - loss: 0.1060 - val_accuracy: 0.8671 - val_loss: 0.3642
# Epoch 52/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.9634 - loss: 0.1181
# Epoch 52: val_accuracy did not improve from 0.95483
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 330ms/step - accuracy: 0.9597 - loss: 0.1158 - val_accuracy: 0.8831 - val_loss: 0.4074
# Epoch 53/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.9681 - loss: 0.0912
# Epoch 53: val_accuracy did not improve from 0.95483
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 332ms/step - accuracy: 0.9513 - loss: 0.1360 - val_accuracy: 0.8237 - val_loss: 0.5602
# Epoch 54/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.9620 - loss: 0.1169
# Epoch 54: val_accuracy did not improve from 0.95483
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 46s 326ms/step - accuracy: 0.9657 - loss: 0.1068 - val_accuracy: 0.3127 - val_loss: 4.6800
# Epoch 55/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.8854 - loss: 0.3099
# Epoch 55: val_accuracy did not improve from 0.95483
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 333ms/step - accuracy: 0.9291 - loss: 0.1967 - val_accuracy: 0.8875 - val_loss: 0.2927
# Epoch 56/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.9671 - loss: 0.1005
# Epoch 56: val_accuracy did not improve from 0.95483
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 327ms/step - accuracy: 0.9575 - loss: 0.1303 - val_accuracy: 0.4438 - val_loss: 3.3860
# Epoch 57/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9626 - loss: 0.1176
# Epoch 57: val_accuracy did not improve from 0.95483
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 48s 334ms/step - accuracy: 0.9666 - loss: 0.0999 - val_accuracy: 0.9380 - val_loss: 0.2074
# Epoch 57: early stopping
# Restoring model weights from the end of the best epoch: 47.
#
# Fold 1 - Validation Accuracy: 0.9548
#
# FOLD 2/5
# Building Stage 2 with 3 blocks, filters=64
#   ✅ Triplet Attention added at Stage 2
# Building Stage 3 with 4 blocks, filters=128
#   ✅ Triplet Attention added at Stage 3
# Building Stage 4 with 6 blocks, filters=256
#   ✅ Triplet Attention added at Stage 4
# Building Stage 5 with 3 blocks, filters=512
#   ✅ Triplet Attention added at Stage 5
# Epoch 1/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 726ms/step - accuracy: 0.3674 - loss: 1.5447
# Epoch 1: val_accuracy improved from None to 0.24978, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold2_best.keras
#
# Epoch 1: finished saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold2_best.keras
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 228s 829ms/step - accuracy: 0.4190 - loss: 1.3146 - val_accuracy: 0.2498 - val_loss: 2.3637
# Epoch 2/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.5392 - loss: 1.0912
# Epoch 2: val_accuracy improved from 0.24978 to 0.26661, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold2_best.keras
#
# Epoch 2: finished saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold2_best.keras
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 49s 344ms/step - accuracy: 0.5635 - loss: 1.0357 - val_accuracy: 0.2666 - val_loss: 2.2149
# Epoch 3/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.6242 - loss: 0.9152
# Epoch 3: val_accuracy improved from 0.26661 to 0.30735, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold2_best.keras
#
# Epoch 3: finished saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold2_best.keras
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 49s 345ms/step - accuracy: 0.6365 - loss: 0.8899 - val_accuracy: 0.3074 - val_loss: 3.0031
# Epoch 4/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.6695 - loss: 0.7957
# Epoch 4: val_accuracy improved from 0.30735 to 0.56687, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold2_best.keras
#
# Epoch 4: finished saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold2_best.keras
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 49s 344ms/step - accuracy: 0.6870 - loss: 0.7741 - val_accuracy: 0.5669 - val_loss: 1.2415
# Epoch 5/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.7193 - loss: 0.7052
# Epoch 5: val_accuracy did not improve from 0.56687
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 332ms/step - accuracy: 0.7229 - loss: 0.7000 - val_accuracy: 0.3853 - val_loss: 3.9344
# Epoch 6/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.7185 - loss: 0.6884
# Epoch 6: val_accuracy did not improve from 0.56687
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 327ms/step - accuracy: 0.7475 - loss: 0.6364 - val_accuracy: 0.4252 - val_loss: 2.6986
# Epoch 7/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.7945 - loss: 0.5701
# Epoch 7: val_accuracy improved from 0.56687 to 0.74756, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold2_best.keras
#
# Epoch 7: finished saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold2_best.keras
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 48s 340ms/step - accuracy: 0.8018 - loss: 0.5480 - val_accuracy: 0.7476 - val_loss: 0.6926
# Epoch 8/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.7862 - loss: 0.5780
# Epoch 8: val_accuracy did not improve from 0.74756
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 329ms/step - accuracy: 0.7984 - loss: 0.5381 - val_accuracy: 0.4659 - val_loss: 2.3862
# Epoch 9/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 0.8205 - loss: 0.5034
# Epoch 9: val_accuracy did not improve from 0.74756
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 46s 324ms/step - accuracy: 0.7843 - loss: 0.5726 - val_accuracy: 0.4048 - val_loss: 1.6477
# Epoch 10/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.7940 - loss: 0.5652
# Epoch 10: val_accuracy did not improve from 0.74756
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 333ms/step - accuracy: 0.8097 - loss: 0.5222 - val_accuracy: 0.6112 - val_loss: 1.7070
# Epoch 11/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.8431 - loss: 0.4364
# Epoch 11: val_accuracy did not improve from 0.74756
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 333ms/step - accuracy: 0.8414 - loss: 0.4382 - val_accuracy: 0.3844 - val_loss: 1.8104
# Epoch 12/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.8421 - loss: 0.4310
# Epoch 12: val_accuracy did not improve from 0.74756
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 329ms/step - accuracy: 0.8421 - loss: 0.4332 - val_accuracy: 0.4438 - val_loss: 1.9446
# Epoch 13/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.8507 - loss: 0.4187
# Epoch 13: val_accuracy did not improve from 0.74756
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 331ms/step - accuracy: 0.8622 - loss: 0.3845 - val_accuracy: 0.6820 - val_loss: 0.9441
# Epoch 14/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.8682 - loss: 0.3698
# Epoch 14: val_accuracy improved from 0.74756 to 0.84411, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold2_best.keras
#
# Epoch 14: finished saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold2_best.keras
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 50s 348ms/step - accuracy: 0.8680 - loss: 0.3600 - val_accuracy: 0.8441 - val_loss: 0.4597
# Epoch 15/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.8874 - loss: 0.3109
# Epoch 15: val_accuracy did not improve from 0.84411
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 328ms/step - accuracy: 0.8600 - loss: 0.3865 - val_accuracy: 0.2985 - val_loss: 4.5369
# Epoch 16/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.8436 - loss: 0.4267
# Epoch 16: val_accuracy did not improve from 0.84411
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 329ms/step - accuracy: 0.8574 - loss: 0.3958 - val_accuracy: 0.6032 - val_loss: 1.9737
# Epoch 17/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.8893 - loss: 0.3269
# Epoch 17: val_accuracy did not improve from 0.84411
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 327ms/step - accuracy: 0.8913 - loss: 0.3165 - val_accuracy: 0.6032 - val_loss: 2.9224
# Epoch 18/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.9009 - loss: 0.2909
# Epoch 18: val_accuracy did not improve from 0.84411
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 48s 337ms/step - accuracy: 0.8955 - loss: 0.2982 - val_accuracy: 0.4951 - val_loss: 1.8908
# Epoch 19/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9043 - loss: 0.2777
# Epoch 19: val_accuracy did not improve from 0.84411
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 48s 334ms/step - accuracy: 0.9099 - loss: 0.2550 - val_accuracy: 0.4801 - val_loss: 4.5015
# Epoch 20/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.9183 - loss: 0.2400
# Epoch 20: val_accuracy did not improve from 0.84411
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 329ms/step - accuracy: 0.9183 - loss: 0.2351 - val_accuracy: 0.7228 - val_loss: 1.0384
# Epoch 21/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.9178 - loss: 0.2433
# Epoch 21: val_accuracy did not improve from 0.84411
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 46s 325ms/step - accuracy: 0.9138 - loss: 0.2589 - val_accuracy: 0.6315 - val_loss: 1.2863
# Epoch 22/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9098 - loss: 0.2435
# Epoch 22: val_accuracy did not improve from 0.84411
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 48s 334ms/step - accuracy: 0.9198 - loss: 0.2313 - val_accuracy: 0.7493 - val_loss: 0.8086
# Epoch 23/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.9154 - loss: 0.2584
# Epoch 23: val_accuracy did not improve from 0.84411
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 329ms/step - accuracy: 0.9085 - loss: 0.2703 - val_accuracy: 0.5678 - val_loss: 1.6490
# Epoch 24/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.9196 - loss: 0.2256
# Epoch 24: val_accuracy did not improve from 0.84411
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 330ms/step - accuracy: 0.9123 - loss: 0.2473 - val_accuracy: 0.7396 - val_loss: 0.8173
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 14.
#
# Fold 2 - Validation Accuracy: 0.8441
#
# FOLD 3/5
# Building Stage 2 with 3 blocks, filters=64
#   ✅ Triplet Attention added at Stage 2
# Building Stage 3 with 4 blocks, filters=128
#   ✅ Triplet Attention added at Stage 3
# Building Stage 4 with 6 blocks, filters=256
#   ✅ Triplet Attention added at Stage 4
# Building Stage 5 with 3 blocks, filters=512
#   ✅ Triplet Attention added at Stage 5
# Epoch 1/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.3635 - loss: 1.4738
# Epoch 1: val_accuracy improved from None to 0.24978, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold3_best.keras
#
# Epoch 1: finished saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold3_best.keras
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 229s 840ms/step - accuracy: 0.4277 - loss: 1.3195 - val_accuracy: 0.2498 - val_loss: 2.5456
# Epoch 2/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.5610 - loss: 1.0483
# Epoch 2: val_accuracy improved from 0.24978 to 0.28698, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold3_best.keras
#
# Epoch 2: finished saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold3_best.keras
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 49s 342ms/step - accuracy: 0.5781 - loss: 1.0079 - val_accuracy: 0.2870 - val_loss: 4.6784
# Epoch 3/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.6380 - loss: 0.9311
# Epoch 3: val_accuracy improved from 0.28698 to 0.37112, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold3_best.keras
#
# Epoch 3: finished saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold3_best.keras
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 49s 344ms/step - accuracy: 0.6410 - loss: 0.9019 - val_accuracy: 0.3711 - val_loss: 2.0255
# Epoch 4/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.6974 - loss: 0.7726
# Epoch 4: val_accuracy improved from 0.37112 to 0.57396, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold3_best.keras
#
# Epoch 4: finished saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold3_best.keras
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 49s 343ms/step - accuracy: 0.7068 - loss: 0.7481 - val_accuracy: 0.5740 - val_loss: 1.5198
# Epoch 5/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.7451 - loss: 0.6516
# Epoch 5: val_accuracy improved from 0.57396 to 0.76528, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold3_best.keras
#
# Epoch 5: finished saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold3_best.keras
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 50s 351ms/step - accuracy: 0.7555 - loss: 0.6324 - val_accuracy: 0.7653 - val_loss: 0.8202
# Epoch 6/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.7726 - loss: 0.5841
# Epoch 6: val_accuracy did not improve from 0.76528
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 331ms/step - accuracy: 0.7725 - loss: 0.5912 - val_accuracy: 0.6492 - val_loss: 1.5675
# Epoch 7/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.8128 - loss: 0.5317
# Epoch 7: val_accuracy did not improve from 0.76528
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 332ms/step - accuracy: 0.8069 - loss: 0.5312 - val_accuracy: 0.5465 - val_loss: 1.2604
# Epoch 8/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.7908 - loss: 0.5526
# Epoch 8: val_accuracy did not improve from 0.76528
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 332ms/step - accuracy: 0.7936 - loss: 0.5380 - val_accuracy: 0.6705 - val_loss: 0.8864
# Epoch 9/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.8071 - loss: 0.5022
# Epoch 9: val_accuracy did not improve from 0.76528
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 326ms/step - accuracy: 0.8186 - loss: 0.4852 - val_accuracy: 0.6129 - val_loss: 1.1058
# Epoch 10/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.8090 - loss: 0.5015
# Epoch 10: val_accuracy did not improve from 0.76528
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 333ms/step - accuracy: 0.8190 - loss: 0.4786 - val_accuracy: 0.7502 - val_loss: 0.7219
# Epoch 11/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.8498 - loss: 0.3976
# Epoch 11: val_accuracy did not improve from 0.76528
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 48s 333ms/step - accuracy: 0.8485 - loss: 0.4190 - val_accuracy: 0.4225 - val_loss: 4.0735
# Epoch 12/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.8590 - loss: 0.4000
# Epoch 12: val_accuracy did not improve from 0.76528
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 329ms/step - accuracy: 0.8633 - loss: 0.3812 - val_accuracy: 0.7414 - val_loss: 0.7755
# Epoch 13/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.8762 - loss: 0.3397
# Epoch 13: val_accuracy did not improve from 0.76528
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 333ms/step - accuracy: 0.8720 - loss: 0.3548 - val_accuracy: 0.6067 - val_loss: 1.3669
# Epoch 14/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.8764 - loss: 0.3297
# Epoch 14: val_accuracy did not improve from 0.76528
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 48s 334ms/step - accuracy: 0.8746 - loss: 0.3473 - val_accuracy: 0.5244 - val_loss: 3.0442
# Epoch 15/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.8665 - loss: 0.3790
# Epoch 15: val_accuracy did not improve from 0.76528
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 329ms/step - accuracy: 0.8738 - loss: 0.3507 - val_accuracy: 0.7511 - val_loss: 0.8982
# Epoch 16/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.8953 - loss: 0.3044
# Epoch 16: val_accuracy improved from 0.76528 to 0.78919, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold3_best.keras
#
# Epoch 16: finished saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold3_best.keras
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 49s 345ms/step - accuracy: 0.8917 - loss: 0.3044 - val_accuracy: 0.7892 - val_loss: 0.6273
# Epoch 17/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.8884 - loss: 0.3423
# Epoch 17: val_accuracy did not improve from 0.78919
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 48s 336ms/step - accuracy: 0.8751 - loss: 0.3570 - val_accuracy: 0.6997 - val_loss: 1.1497
# Epoch 18/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.9072 - loss: 0.2678
# Epoch 18: val_accuracy did not improve from 0.78919
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 46s 325ms/step - accuracy: 0.9085 - loss: 0.2610 - val_accuracy: 0.7697 - val_loss: 0.8190
# Epoch 19/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9024 - loss: 0.2750
# Epoch 19: val_accuracy did not improve from 0.78919
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 328ms/step - accuracy: 0.9079 - loss: 0.2618 - val_accuracy: 0.6368 - val_loss: 1.0385
# Epoch 20/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9225 - loss: 0.2234
# Epoch 20: val_accuracy did not improve from 0.78919
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 48s 334ms/step - accuracy: 0.9181 - loss: 0.2318 - val_accuracy: 0.3313 - val_loss: 4.7264
# Epoch 21/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.8843 - loss: 0.3050
# Epoch 21: val_accuracy did not improve from 0.78919
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 48s 333ms/step - accuracy: 0.8879 - loss: 0.2999 - val_accuracy: 0.4579 - val_loss: 5.2621
# Epoch 22/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.9066 - loss: 0.2544
# Epoch 22: val_accuracy did not improve from 0.78919
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 327ms/step - accuracy: 0.8997 - loss: 0.2719 - val_accuracy: 0.7050 - val_loss: 1.0885
# Epoch 23/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.9086 - loss: 0.2442
# Epoch 23: val_accuracy improved from 0.78919 to 0.81665, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold3_best.keras
#
# Epoch 23: finished saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold3_best.keras
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 48s 339ms/step - accuracy: 0.9099 - loss: 0.2486 - val_accuracy: 0.8167 - val_loss: 0.6097
# Epoch 24/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9253 - loss: 0.2105
# Epoch 24: val_accuracy did not improve from 0.81665
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 49s 342ms/step - accuracy: 0.9156 - loss: 0.2343 - val_accuracy: 0.8069 - val_loss: 0.6124
# Epoch 25/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.9274 - loss: 0.2043
# Epoch 25: val_accuracy did not improve from 0.81665
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 329ms/step - accuracy: 0.9274 - loss: 0.2095 - val_accuracy: 0.7865 - val_loss: 0.6675
# Epoch 26/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.9336 - loss: 0.1912
# Epoch 26: val_accuracy improved from 0.81665 to 0.83348, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold3_best.keras
#
# Epoch 26: finished saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold3_best.keras
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 50s 348ms/step - accuracy: 0.9322 - loss: 0.1917 - val_accuracy: 0.8335 - val_loss: 0.6243
# Epoch 27/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.9244 - loss: 0.2024
# Epoch 27: val_accuracy did not improve from 0.83348
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 331ms/step - accuracy: 0.9256 - loss: 0.2049 - val_accuracy: 0.8051 - val_loss: 0.5242
# Epoch 28/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.9324 - loss: 0.2028
# Epoch 28: val_accuracy did not improve from 0.83348
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 332ms/step - accuracy: 0.9309 - loss: 0.1987 - val_accuracy: 0.6997 - val_loss: 1.1466
# Epoch 29/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.9143 - loss: 0.2314
# Epoch 29: val_accuracy did not improve from 0.83348
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 48s 338ms/step - accuracy: 0.9258 - loss: 0.2078 - val_accuracy: 0.8113 - val_loss: 0.6942
# Epoch 30/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.9519 - loss: 0.1444
# Epoch 30: val_accuracy improved from 0.83348 to 0.89371, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold3_best.keras
#
# Epoch 30: finished saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold3_best.keras
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 50s 354ms/step - accuracy: 0.9497 - loss: 0.1548 - val_accuracy: 0.8937 - val_loss: 0.3239
# Epoch 31/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.8835 - loss: 0.3290
# Epoch 31: val_accuracy did not improve from 0.89371
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 332ms/step - accuracy: 0.8802 - loss: 0.3399 - val_accuracy: 0.7733 - val_loss: 0.7190
# Epoch 32/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.9256 - loss: 0.2231
# Epoch 32: val_accuracy did not improve from 0.89371
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 48s 335ms/step - accuracy: 0.9267 - loss: 0.2064 - val_accuracy: 0.7228 - val_loss: 0.7582
# Epoch 33/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.9418 - loss: 0.1702
# Epoch 33: val_accuracy did not improve from 0.89371
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 48s 335ms/step - accuracy: 0.9444 - loss: 0.1605 - val_accuracy: 0.6900 - val_loss: 1.6575
# Epoch 34/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.9213 - loss: 0.2342
# Epoch 34: val_accuracy did not improve from 0.89371
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 332ms/step - accuracy: 0.9189 - loss: 0.2398 - val_accuracy: 0.8158 - val_loss: 0.5417
# Epoch 35/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.9253 - loss: 0.2225
# Epoch 35: val_accuracy improved from 0.89371 to 0.91763, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold3_best.keras
#
# Epoch 35: finished saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold3_best.keras
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 49s 345ms/step - accuracy: 0.9333 - loss: 0.1916 - val_accuracy: 0.9176 - val_loss: 0.2286
# Epoch 36/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.9466 - loss: 0.1524
# Epoch 36: val_accuracy did not improve from 0.91763
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 333ms/step - accuracy: 0.9433 - loss: 0.1609 - val_accuracy: 0.8237 - val_loss: 0.5876
# Epoch 37/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.9479 - loss: 0.1528
# Epoch 37: val_accuracy did not improve from 0.91763
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 332ms/step - accuracy: 0.9402 - loss: 0.1784 - val_accuracy: 0.8689 - val_loss: 0.4122
# Epoch 38/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.9313 - loss: 0.1964
# Epoch 38: val_accuracy did not improve from 0.91763
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 48s 340ms/step - accuracy: 0.9398 - loss: 0.1789 - val_accuracy: 0.6129 - val_loss: 1.6452
# Epoch 39/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9564 - loss: 0.1278
# Epoch 39: val_accuracy did not improve from 0.91763
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 328ms/step - accuracy: 0.9588 - loss: 0.1162 - val_accuracy: 0.8964 - val_loss: 0.3229
# Epoch 40/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.9564 - loss: 0.1229
# Epoch 40: val_accuracy did not improve from 0.91763
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 49s 341ms/step - accuracy: 0.9542 - loss: 0.1342 - val_accuracy: 0.7334 - val_loss: 1.1196
# Epoch 41/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.9605 - loss: 0.1148
# Epoch 41: val_accuracy did not improve from 0.91763
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 330ms/step - accuracy: 0.9548 - loss: 0.1290 - val_accuracy: 0.8565 - val_loss: 0.4342
# Epoch 42/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.9614 - loss: 0.1086
# Epoch 42: val_accuracy did not improve from 0.91763
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 328ms/step - accuracy: 0.9617 - loss: 0.1094 - val_accuracy: 0.7201 - val_loss: 1.0741
# Epoch 43/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.9580 - loss: 0.1304
# Epoch 43: val_accuracy did not improve from 0.91763
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 332ms/step - accuracy: 0.9477 - loss: 0.1518 - val_accuracy: 0.7210 - val_loss: 1.3899
# Epoch 44/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.9586 - loss: 0.1165
# Epoch 44: val_accuracy did not improve from 0.91763
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 330ms/step - accuracy: 0.9528 - loss: 0.1310 - val_accuracy: 0.9035 - val_loss: 0.3095
# Epoch 45/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.9623 - loss: 0.1080
# Epoch 45: val_accuracy did not improve from 0.91763
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 333ms/step - accuracy: 0.9608 - loss: 0.1128 - val_accuracy: 0.8973 - val_loss: 0.3754
# Epoch 45: early stopping
# Restoring model weights from the end of the best epoch: 35.
#
# Fold 3 - Validation Accuracy: 0.9176
#
# FOLD 4/5
# Building Stage 2 with 3 blocks, filters=64
#   ✅ Triplet Attention added at Stage 2
# Building Stage 3 with 4 blocks, filters=128
#   ✅ Triplet Attention added at Stage 3
# Building Stage 4 with 6 blocks, filters=256
#   ✅ Triplet Attention added at Stage 4
# Building Stage 5 with 3 blocks, filters=512
#   ✅ Triplet Attention added at Stage 5
# Epoch 1/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 742ms/step - accuracy: 0.3811 - loss: 1.4841
# Epoch 1: val_accuracy improved from None to 0.25066, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold4_best.keras
#
# Epoch 1: finished saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold4_best.keras
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 232s 852ms/step - accuracy: 0.4372 - loss: 1.2766 - val_accuracy: 0.2507 - val_loss: 2.1067
# Epoch 2/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.5414 - loss: 1.0776
# Epoch 2: val_accuracy improved from 0.25066 to 0.27281, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold4_best.keras
#
# Epoch 2: finished saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold4_best.keras
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 51s 355ms/step - accuracy: 0.5491 - loss: 1.0570 - val_accuracy: 0.2728 - val_loss: 1.5102
# Epoch 3/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.5672 - loss: 1.0015
# Epoch 3: val_accuracy improved from 0.27281 to 0.60496, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold4_best.keras
#
# Epoch 3: finished saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold4_best.keras
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 49s 343ms/step - accuracy: 0.6086 - loss: 0.9310 - val_accuracy: 0.6050 - val_loss: 0.9960
# Epoch 4/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.6995 - loss: 0.7719
# Epoch 4: val_accuracy did not improve from 0.60496
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 48s 339ms/step - accuracy: 0.6875 - loss: 0.7749 - val_accuracy: 0.5757 - val_loss: 1.2605
# Epoch 5/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.7175 - loss: 0.7121
# Epoch 5: val_accuracy did not improve from 0.60496
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 48s 336ms/step - accuracy: 0.7025 - loss: 0.7424 - val_accuracy: 0.3826 - val_loss: 3.5836
# Epoch 6/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.7456 - loss: 0.6470
# Epoch 6: val_accuracy did not improve from 0.60496
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 48s 334ms/step - accuracy: 0.7568 - loss: 0.6250 - val_accuracy: 0.4606 - val_loss: 3.1562
# Epoch 7/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.7773 - loss: 0.5821
# Epoch 7: val_accuracy did not improve from 0.60496
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 332ms/step - accuracy: 0.7856 - loss: 0.5695 - val_accuracy: 0.5270 - val_loss: 1.2221
# Epoch 8/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.8089 - loss: 0.5144
# Epoch 8: val_accuracy did not improve from 0.60496
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 49s 344ms/step - accuracy: 0.8042 - loss: 0.5256 - val_accuracy: 0.5678 - val_loss: 1.1363
# Epoch 9/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.8353 - loss: 0.4367
# Epoch 9: val_accuracy improved from 0.60496 to 0.71745, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold4_best.keras
#
# Epoch 9: finished saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold4_best.keras
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 50s 351ms/step - accuracy: 0.8432 - loss: 0.4228 - val_accuracy: 0.7174 - val_loss: 0.8242
# Epoch 10/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.8498 - loss: 0.4139
# Epoch 10: val_accuracy improved from 0.71745 to 0.77502, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold4_best.keras
#
# Epoch 10: finished saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold4_best.keras
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 51s 357ms/step - accuracy: 0.8427 - loss: 0.4282 - val_accuracy: 0.7750 - val_loss: 0.6026
# Epoch 11/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.8772 - loss: 0.3407
# Epoch 11: val_accuracy did not improve from 0.77502
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 48s 334ms/step - accuracy: 0.8751 - loss: 0.3432 - val_accuracy: 0.6997 - val_loss: 0.9346
# Epoch 12/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.8649 - loss: 0.3747
# Epoch 12: val_accuracy did not improve from 0.77502
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 332ms/step - accuracy: 0.8726 - loss: 0.3453 - val_accuracy: 0.7272 - val_loss: 0.8768
# Epoch 13/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.8845 - loss: 0.3254
# Epoch 13: val_accuracy did not improve from 0.77502
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 48s 335ms/step - accuracy: 0.8882 - loss: 0.3229 - val_accuracy: 0.6218 - val_loss: 1.3819
# Epoch 14/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.8826 - loss: 0.3301
# Epoch 14: val_accuracy did not improve from 0.77502
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 331ms/step - accuracy: 0.8877 - loss: 0.3123 - val_accuracy: 0.5368 - val_loss: 1.7366
# Epoch 15/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.8922 - loss: 0.2962
# Epoch 15: val_accuracy did not improve from 0.77502
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 331ms/step - accuracy: 0.8937 - loss: 0.2985 - val_accuracy: 0.5146 - val_loss: 3.5822
# Epoch 16/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.9087 - loss: 0.2632
# Epoch 16: val_accuracy did not improve from 0.77502
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 48s 335ms/step - accuracy: 0.9096 - loss: 0.2591 - val_accuracy: 0.6802 - val_loss: 1.0411
# Epoch 17/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.8830 - loss: 0.3344
# Epoch 17: val_accuracy improved from 0.77502 to 0.83260, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold4_best.keras
#
# Epoch 17: finished saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold4_best.keras
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 51s 357ms/step - accuracy: 0.8711 - loss: 0.3652 - val_accuracy: 0.8326 - val_loss: 0.4647
# Epoch 18/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.9061 - loss: 0.2422
# Epoch 18: val_accuracy improved from 0.83260 to 0.84411, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold4_best.keras
#
# Epoch 18: finished saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold4_best.keras
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 49s 347ms/step - accuracy: 0.9056 - loss: 0.2534 - val_accuracy: 0.8441 - val_loss: 0.4331
# Epoch 19/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.9132 - loss: 0.2339
# Epoch 19: val_accuracy did not improve from 0.84411
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 48s 337ms/step - accuracy: 0.9074 - loss: 0.2573 - val_accuracy: 0.7830 - val_loss: 0.7540
# Epoch 20/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9028 - loss: 0.2724
# Epoch 20: val_accuracy did not improve from 0.84411
# ...
#
# Epoch 5: finished saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold5_best.keras
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 49s 344ms/step - accuracy: 0.7276 - loss: 0.6983 - val_accuracy: 0.6534 - val_loss: 0.8987
# Epoch 6/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.7492 - loss: 0.6273
# Epoch 6: val_accuracy did not improve from 0.65337
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 330ms/step - accuracy: 0.7653 - loss: 0.6082 - val_accuracy: 0.3777 - val_loss: 3.9950
# Epoch 7/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.7980 - loss: 0.5429
# Epoch 7: val_accuracy did not improve from 0.65337
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 48s 336ms/step - accuracy: 0.8034 - loss: 0.5343 - val_accuracy: 0.6418 - val_loss: 1.0332
# Epoch 8/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.8229 - loss: 0.5021
# Epoch 8: val_accuracy did not improve from 0.65337
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 48s 334ms/step - accuracy: 0.8240 - loss: 0.4848 - val_accuracy: 0.5567 - val_loss: 1.2527
# Epoch 9/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.8401 - loss: 0.4138
# Epoch 9: val_accuracy improved from 0.65337 to 0.70213, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold5_best.keras
#
# Epoch 9: finished saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold5_best.keras
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 49s 345ms/step - accuracy: 0.8353 - loss: 0.4300 - val_accuracy: 0.7021 - val_loss: 0.8751
# Epoch 10/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.8448 - loss: 0.4295
# Epoch 10: val_accuracy did not improve from 0.70213
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 48s 336ms/step - accuracy: 0.8457 - loss: 0.4161 - val_accuracy: 0.5727 - val_loss: 1.3778
# Epoch 11/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.8516 - loss: 0.4266
# Epoch 11: val_accuracy did not improve from 0.70213
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 330ms/step - accuracy: 0.8616 - loss: 0.3905 - val_accuracy: 0.6525 - val_loss: 1.3449
# Epoch 12/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.8610 - loss: 0.3646
# Epoch 12: val_accuracy did not improve from 0.70213
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 48s 335ms/step - accuracy: 0.8570 - loss: 0.3720 - val_accuracy: 0.6711 - val_loss: 1.7199
# Epoch 13/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.8760 - loss: 0.3427
# Epoch 13: val_accuracy did not improve from 0.70213
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 330ms/step - accuracy: 0.8676 - loss: 0.3705 - val_accuracy: 0.3005 - val_loss: 5.6080
# Epoch 14/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.8830 - loss: 0.3288
# Epoch 14: val_accuracy did not improve from 0.70213
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 332ms/step - accuracy: 0.8793 - loss: 0.3339 - val_accuracy: 0.6702 - val_loss: 1.1288
# Epoch 15/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.8874 - loss: 0.2949
# Epoch 15: val_accuracy did not improve from 0.70213
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 48s 337ms/step - accuracy: 0.8857 - loss: 0.3087 - val_accuracy: 0.5966 - val_loss: 1.5557
# Epoch 16/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.8964 - loss: 0.2832
# Epoch 16: val_accuracy improved from 0.70213 to 0.75709, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold5_best.keras
#
# Epoch 16: finished saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold5_best.keras
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 50s 349ms/step - accuracy: 0.8944 - loss: 0.2829 - val_accuracy: 0.7571 - val_loss: 0.6780
# Epoch 17/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9014 - loss: 0.2828
# Epoch 17: val_accuracy did not improve from 0.75709
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 48s 334ms/step - accuracy: 0.8966 - loss: 0.2880 - val_accuracy: 0.6436 - val_loss: 1.0543
# Epoch 18/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.9199 - loss: 0.2363
# Epoch 18: val_accuracy did not improve from 0.75709
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 48s 335ms/step - accuracy: 0.9110 - loss: 0.2570 - val_accuracy: 0.4096 - val_loss: 2.8681
# Epoch 19/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.8980 - loss: 0.2895
# Epoch 19: val_accuracy improved from 0.75709 to 0.78014, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold5_best.keras
#
# Epoch 19: finished saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold5_best.keras
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 49s 347ms/step - accuracy: 0.9032 - loss: 0.2729 - val_accuracy: 0.7801 - val_loss: 0.8651
# Epoch 20/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.9151 - loss: 0.2406
# Epoch 20: val_accuracy improved from 0.78014 to 0.85195, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold5_best.keras
#
# Epoch 20: finished saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold5_best.keras
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 49s 347ms/step - accuracy: 0.9136 - loss: 0.2511 - val_accuracy: 0.8520 - val_loss: 0.4939
# Epoch 21/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.9294 - loss: 0.1906
# Epoch 21: val_accuracy did not improve from 0.85195
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 329ms/step - accuracy: 0.9097 - loss: 0.2416 - val_accuracy: 0.6108 - val_loss: 0.9745
# Epoch 22/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.9164 - loss: 0.2390
# Epoch 22: val_accuracy did not improve from 0.85195
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 333ms/step - accuracy: 0.9134 - loss: 0.2558 - val_accuracy: 0.6507 - val_loss: 0.8675
# Epoch 23/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.9042 - loss: 0.2611
# Epoch 23: val_accuracy did not improve from 0.85195
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 48s 335ms/step - accuracy: 0.9249 - loss: 0.2145 - val_accuracy: 0.6906 - val_loss: 1.1431
# Epoch 24/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.9217 - loss: 0.1988
# Epoch 24: val_accuracy improved from 0.85195 to 0.87943, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold5_best.keras
#
# Epoch 24: finished saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold5_best.keras
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 50s 350ms/step - accuracy: 0.9218 - loss: 0.2140 - val_accuracy: 0.8794 - val_loss: 0.4369
# Epoch 25/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.9311 - loss: 0.1921
# Epoch 25: val_accuracy did not improve from 0.87943
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 48s 340ms/step - accuracy: 0.9289 - loss: 0.1963 - val_accuracy: 0.6507 - val_loss: 1.5269
# Epoch 26/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.9557 - loss: 0.1264
# Epoch 26: val_accuracy did not improve from 0.87943
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 49s 346ms/step - accuracy: 0.9331 - loss: 0.1830 - val_accuracy: 0.6950 - val_loss: 0.9115
# Epoch 27/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.8970 - loss: 0.2903
# Epoch 27: val_accuracy did not improve from 0.87943
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 331ms/step - accuracy: 0.8791 - loss: 0.3405 - val_accuracy: 0.7092 - val_loss: 0.9442
# Epoch 28/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.9315 - loss: 0.1986
# Epoch 28: val_accuracy did not improve from 0.87943
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 48s 335ms/step - accuracy: 0.9271 - loss: 0.2079 - val_accuracy: 0.8342 - val_loss: 0.4546
# Epoch 29/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.9197 - loss: 0.2190
# Epoch 29: val_accuracy did not improve from 0.87943
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 332ms/step - accuracy: 0.9159 - loss: 0.2322 - val_accuracy: 0.8138 - val_loss: 0.7039
# Epoch 30/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.9367 - loss: 0.1912
# Epoch 30: val_accuracy did not improve from 0.87943
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 48s 336ms/step - accuracy: 0.9243 - loss: 0.2279 - val_accuracy: 0.7598 - val_loss: 0.8741
# Epoch 31/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.9358 - loss: 0.1843
# Epoch 31: val_accuracy did not improve from 0.87943
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 333ms/step - accuracy: 0.9243 - loss: 0.2141 - val_accuracy: 0.6809 - val_loss: 1.1009
# Epoch 32/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.9337 - loss: 0.1921
# Epoch 32: val_accuracy improved from 0.87943 to 0.93528, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold5_best.keras
#
# Epoch 32: finished saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold5_best.keras
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 50s 352ms/step - accuracy: 0.9369 - loss: 0.1826 - val_accuracy: 0.9353 - val_loss: 0.2490
# Epoch 33/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.9445 - loss: 0.1557
# Epoch 33: val_accuracy did not improve from 0.93528
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 49s 345ms/step - accuracy: 0.9424 - loss: 0.1591 - val_accuracy: 0.7961 - val_loss: 0.6980
# Epoch 34/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9377 - loss: 0.1735
# Epoch 34: val_accuracy did not improve from 0.93528
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 48s 334ms/step - accuracy: 0.9329 - loss: 0.1878 - val_accuracy: 0.6622 - val_loss: 1.8299
# Epoch 35/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9287 - loss: 0.2032
# Epoch 35: val_accuracy did not improve from 0.93528
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 48s 334ms/step - accuracy: 0.9393 - loss: 0.1758 - val_accuracy: 0.5904 - val_loss: 1.4876
# Epoch 36/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.9493 - loss: 0.1426
# Epoch 36: val_accuracy did not improve from 0.93528
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 330ms/step - accuracy: 0.9356 - loss: 0.1807 - val_accuracy: 0.7970 - val_loss: 0.6899
# Epoch 37/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.9503 - loss: 0.1465
# Epoch 37: val_accuracy did not improve from 0.93528
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 331ms/step - accuracy: 0.9426 - loss: 0.1743 - val_accuracy: 0.6472 - val_loss: 1.3088
# Epoch 38/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.9568 - loss: 0.1190
# Epoch 38: val_accuracy did not improve from 0.93528
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 48s 338ms/step - accuracy: 0.9601 - loss: 0.1133 - val_accuracy: 0.8830 - val_loss: 0.4589
# Epoch 39/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.9570 - loss: 0.1182
# Epoch 39: val_accuracy did not improve from 0.93528
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 48s 337ms/step - accuracy: 0.9573 - loss: 0.1179 - val_accuracy: 0.8378 - val_loss: 0.4514
# Epoch 40/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.9504 - loss: 0.1453
# Epoch 40: val_accuracy did not improve from 0.93528
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 331ms/step - accuracy: 0.9480 - loss: 0.1538 - val_accuracy: 0.8236 - val_loss: 0.6394
# Epoch 41/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.9546 - loss: 0.1323
# Epoch 41: val_accuracy did not improve from 0.93528
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 48s 333ms/step - accuracy: 0.9559 - loss: 0.1323 - val_accuracy: 0.9309 - val_loss: 0.2339
# Epoch 42/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9442 - loss: 0.1522
# Epoch 42: val_accuracy did not improve from 0.93528
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 48s 334ms/step - accuracy: 0.9495 - loss: 0.1372 - val_accuracy: 0.7642 - val_loss: 0.8707
# Epoch 43/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.9660 - loss: 0.0942
# Epoch 43: val_accuracy did not improve from 0.93528
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 48s 338ms/step - accuracy: 0.9626 - loss: 0.1030 - val_accuracy: 0.8989 - val_loss: 0.3020
# Epoch 44/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.9679 - loss: 0.0941
# Epoch 44: val_accuracy did not improve from 0.93528
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 48s 337ms/step - accuracy: 0.9624 - loss: 0.1068 - val_accuracy: 0.8183 - val_loss: 0.5711
# Epoch 45/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.9572 - loss: 0.1127
# Epoch 45: val_accuracy did not improve from 0.93528
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 330ms/step - accuracy: 0.9590 - loss: 0.1100 - val_accuracy: 0.7828 - val_loss: 0.6719
# Epoch 46/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.9687 - loss: 0.0898
# Epoch 46: val_accuracy did not improve from 0.93528
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 48s 336ms/step - accuracy: 0.9686 - loss: 0.0959 - val_accuracy: 0.7668 - val_loss: 0.8076
# Epoch 47/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.9183 - loss: 0.2445
# Epoch 47: val_accuracy did not improve from 0.93528
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 332ms/step - accuracy: 0.9440 - loss: 0.1656 - val_accuracy: 0.8449 - val_loss: 0.6482
# Epoch 48/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.9717 - loss: 0.0925
# Epoch 48: val_accuracy improved from 0.93528 to 0.94592, saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold5_best.keras
#
# Epoch 48: finished saving model to /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold5_best.keras
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 51s 355ms/step - accuracy: 0.9697 - loss: 0.0936 - val_accuracy: 0.9459 - val_loss: 0.1697
# Epoch 49/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.9706 - loss: 0.0930
# Epoch 49: val_accuracy did not improve from 0.94592
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 49s 341ms/step - accuracy: 0.9610 - loss: 0.1208 - val_accuracy: 0.8892 - val_loss: 0.3746
# Epoch 50/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.9642 - loss: 0.1019
# Epoch 50: val_accuracy did not improve from 0.94592
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 49s 340ms/step - accuracy: 0.9681 - loss: 0.0903 - val_accuracy: 0.6525 - val_loss: 1.3971
# Epoch 51/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.9538 - loss: 0.1492
# Epoch 51: val_accuracy did not improve from 0.94592
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 49s 341ms/step - accuracy: 0.9495 - loss: 0.1557 - val_accuracy: 0.9220 - val_loss: 0.2715
# Epoch 52/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.9691 - loss: 0.0802
# Epoch 52: val_accuracy did not improve from 0.94592
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 331ms/step - accuracy: 0.9683 - loss: 0.0888 - val_accuracy: 0.8874 - val_loss: 0.3851
# Epoch 53/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.9718 - loss: 0.0796
# Epoch 53: val_accuracy did not improve from 0.94592
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 333ms/step - accuracy: 0.9650 - loss: 0.0931 - val_accuracy: 0.8324 - val_loss: 0.6783
# Epoch 54/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9415 - loss: 0.1714
# Epoch 54: val_accuracy did not improve from 0.94592
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 48s 335ms/step - accuracy: 0.9407 - loss: 0.1742 - val_accuracy: 0.8502 - val_loss: 0.5654
# Epoch 55/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.9754 - loss: 0.0660
# Epoch 55: val_accuracy did not improve from 0.94592
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 47s 332ms/step - accuracy: 0.9752 - loss: 0.0676 - val_accuracy: 0.7633 - val_loss: 0.7867
# Epoch 56/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.9739 - loss: 0.0736
# Epoch 56: val_accuracy did not improve from 0.94592
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 48s 339ms/step - accuracy: 0.9714 - loss: 0.0827 - val_accuracy: 0.9344 - val_loss: 0.2523
# Epoch 57/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9765 - loss: 0.0637
# Epoch 57: val_accuracy did not improve from 0.94592
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 48s 334ms/step - accuracy: 0.9748 - loss: 0.0687 - val_accuracy: 0.9406 - val_loss: 0.2432
# Epoch 58/100
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.9748 - loss: 0.0757
# Epoch 58: val_accuracy did not improve from 0.94592
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 48s 340ms/step - accuracy: 0.9732 - loss: 0.0799 - val_accuracy: 0.8342 - val_loss: 0.5128
# Epoch 58: early stopping
# Restoring model weights from the end of the best epoch: 48.
#
# Fold 5 - Validation Accuracy: 0.9459

# %%
# K-Fold Results Summary
print("K-FOLD CROSS VALIDATION RESULTS")

fold_accuracies = [score['val_accuracy'] for score in fold_scores]
print(f"Fold Accuracies: {[f'{acc:.4f}' for acc in fold_accuracies]}")
print(f"\nMean Accuracy: {np.mean(fold_accuracies):.4f}")
print(f"Best Fold: {np.argmax(fold_accuracies) + 1} with accuracy {np.max(fold_accuracies):.4f}")
# Out:
# K-FOLD CROSS VALIDATION RESULTS
# Fold Accuracies: ['0.9548', '0.8441', '0.9176', '0.9327', '0.9459']
#
# Mean Accuracy: 0.9190
# Best Fold: 1 with accuracy 0.9548

# %%
# Final Evaluation pada Test Set (Unseen Data)
print(f"\n{'='*60}")
print("FINAL EVALUATION ON UNSEEN TEST SET")
print(f"Using: {'AVG (Average of all {K_FOLDS} folds)' if USE_AVG else f'BEST FOLD (Fold {np.argmax(fold_accuracies) + 1})'}")
print(f"{'='*60}\n")

y_test_cat = tf.keras.utils.to_categorical(y_test, NUM_CLASSES)

if USE_AVG:
    # AVG: Rata-rata prediksi dari semua fold
    print("Generating predictions from all folds (Averaging)...")
    all_predictions = []

    for i, model in enumerate(fold_models):
        pred = model.predict(X_test, verbose=0)
        all_predictions.append(pred)
        print(f"  Fold {i+1} predictions generated")

    # Average predictions (Model Averaging)
    y_pred_probs = np.mean(all_predictions, axis=0)
    y_pred = np.argmax(y_pred_probs, axis=1)

    # Calculate average loss
    test_loss = tf.keras.losses.categorical_crossentropy(y_test_cat, y_pred_probs).numpy().mean()
    test_acc = accuracy_score(y_test, y_pred)

    print(f"\nAverage Model Test Loss: {test_loss:.4f}")
    print(f"Average Model Test Accuracy: {test_acc:.4f}\n")

else:
    # BEST FOLD: Gunakan model terbaik saja
    best_fold_idx = np.argmax(fold_accuracies)
    best_model = fold_models[best_fold_idx]
    print(f"Using model from Fold {best_fold_idx + 1}")

    test_loss, test_acc = best_model.evaluate(X_test, y_test_cat, verbose=0)
    y_pred_probs = best_model.predict(X_test, verbose=0)
    y_pred = np.argmax(y_pred_probs, axis=1)

    print(f"\nBest Fold Test Loss: {test_loss:.4f}")
    print(f"Best Fold Test Accuracy: {test_acc:.4f}\n")

# Classification Report
print("Classification Report:")
print(classification_report(y_test, y_pred, target_names=class_names))

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)

plt.title(f'Confusion Matrix - Test Set (Baseline)\n{"Average Mode" if USE_AVG else "Best Fold"}')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.tight_layout()
plt.savefig('/content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_matrix.png', dpi=300)
plt.show()
# Out:
# ============================================================
# FINAL EVALUATION ON UNSEEN TEST SET
# Using: AVG (Average of all {K_FOLDS} folds)
# ============================================================
#
# Generating predictions from all folds (Averaging)...
#   Fold 1 predictions generated
#   Fold 2 predictions generated
#   Fold 3 predictions generated
#   Fold 4 predictions generated
#   Fold 5 predictions generated
#
# Average Model Test Loss: 0.1563
# Average Model Test Accuracy: 0.9728
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        blast       0.97      0.98      0.98       348
#   brown_spot       0.96      0.97      0.97       193
#        hispa       0.98      0.97      0.98       319
#       normal       0.97      0.97      0.97       353
#
#     accuracy                           0.97      1213
#    macro avg       0.97      0.97      0.97      1213
# weighted avg       0.97      0.97      0.97      1213

# %%
# plot hasil 5 fold
plt.figure(figsize=(14, 5))

# --- PLOT AKURASI (KIRI) ---
plt.subplot(1, 2, 1)
for i, h in enumerate(fold_histories):
    # Plot tiap fold dengan warna abu-abu
    plt.plot(h['val_accuracy'], label=f'Fold {i+1}', alpha=0.5)

plt.title('Akurasi Validasi (5 Fold)')
plt.xlabel('Epoch')
plt.ylabel('Akurasi')
plt.legend()
plt.grid(True)

# --- PLOT LOSS (KANAN) ---
plt.subplot(1, 2, 2)
for i, h in enumerate(fold_histories):
    # Plot tiap fold dengan warna abu-abu
    plt.plot(h['val_loss'], label=f'Fold {i+1}', alpha=0.5)

plt.title('Loss Validasi (5 Fold)')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.savefig('/content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/training_history_baseline.png', dpi=300)
plt.show()

# %%
plt.figure(figsize=(15, 12))

for i, class_name in enumerate(class_names):
    # ambil semua index yang termasuk kelas ini
    indices = np.where(y_test == i)[0]
    # pilih 5 secara acak
    selected_indices = np.random.choice(indices, 5, replace=False)

    for j, idx in enumerate(selected_indices):
        plt.subplot(NUM_CLASSES, 5, i * 5 + j + 1)
        plt.imshow(X_test[idx])

        # prediksi vs Asli
        p_idx = y_pred[idx]
        is_correct = (i == p_idx)

        title = f"Actual: {class_name}\nPred: {class_names[p_idx]}"
        plt.title(title, color='green' if is_correct else 'red', fontsize=9)
        plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Save Models & Results

# Save semua model fold (format .keras)
for i, model in enumerate(fold_models):
    model_path = f'/content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold{i+1}_final.keras'
    model.save(model_path)
    print(f"Fold {i+1} model saved: {model_path}")

# Save hasil k-fold
results = {
    'fold_scores': fold_scores,
    'fold_histories': fold_histories,
    'test_accuracy': test_acc,
    'test_loss': test_loss,
    'class_names': class_names,
    'confusion_matrix': cm,
    'use_avg': USE_AVG,
    'num_folds': K_FOLDS,
    'mean_val_accuracy': np.mean(fold_accuracies),
    'std_val_accuracy': np.std(fold_accuracies),
    'predictions': y_pred,
    'prediction_probs': y_pred_probs,
    'model_type': 'baseline'
}

with open('/content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/kfold_results_skenario 2A.pkl', 'wb') as f:
    pickle.dump(results, f)

print(f"\nResults saved to: /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/kfold_results_skenario 2A.pkl")


print(f"\nFinal Test Accuracy: {test_acc:.4f}")
print(f"Model saved: /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/")
print(f"Format: .keras")
if USE_AVG:
    print(f"Mode: AVG ({K_FOLDS} models)")
else:
    print(f"Mode: BEST FOLD (Fold {np.argmax(fold_accuracies) + 1})")
# Out:
# Fold 1 model saved: /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold1_final.keras
# Fold 2 model saved: /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold2_final.keras
# Fold 3 model saved: /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold3_final.keras
# Fold 4 model saved: /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold4_final.keras
# Fold 5 model saved: /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/skenario2A_fold5_final.keras
#
# Results saved to: /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/kfold_results_skenario 2A.pkl
#
# Final Test Accuracy: 0.9728
# Model saved: /content/drive/MyDrive/22-023_Ali Ridho/models/Skenario 2 A/
# Format: .keras
# Mode: AVG (5 models)
